# %% [markdown]
# # Imbalanced Learn with Stacking for $Y(2)$

# %% [markdown]
# ## Setup

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Common imports
import numpy as np
import pandas as pd

from sklearn.model_selection import (
    cross_val_predict, cross_validate,
    RepeatedStratifiedKFold,
)

from imblearn.over_sampling import (
    RandomOverSampler, SMOTE, ADASYN, BorderlineSMOTE
)
from imblearn.under_sampling import (
    AllKNN,
    CondensedNearestNeighbour,
    EditedNearestNeighbours,
    InstanceHardnessThreshold,
    OneSidedSelection,
    RandomUnderSampler,
    NeighbourhoodCleaningRule,
    RepeatedEditedNearestNeighbours,
    TomekLinks,
)
from imblearn.combine import SMOTEENN, SMOTETomek
from imblearn.pipeline import Pipeline
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from catboost import CatBoostClassifier

# %% [markdown]
# ## Data Loading

# %%
seed = 42
dataset = pd.read_csv(f"datasets/train_set_{seed}_t_2.csv")

# %% [markdown]
# Separating validation set

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.25, random_state=42)
for train_index, valid_index in split.split(dataset, dataset['is_drop']):
    train_set = dataset.loc[train_index]
    valid_set = dataset.loc[valid_index]

train_set.reset_index(inplace=True, drop=True)
valid_set.reset_index(inplace=True, drop=True)

# %% [markdown]
# Separate features and labels from the train-set and valid-set

# %%
X_tr = train_set.drop(['is_drop'], axis=1)
y_tr = train_set['is_drop'].copy()

X_va = valid_set.drop(['is_drop'], axis=1)
y_va = valid_set['is_drop'].copy()

X_tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19054 entries, 0 to 19053
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index_o            19054 non-null  int64
#  1   year               19054 non-null  int64
#  2   semester           19054 non-null  int64
#  3   grade              19054 non-null  int64
#  4   sex                19054 non-null  object
#  5   gpa_last_seme      19054 non-null  float64
#  6   credits_last_seme  19054 non-null  float64
#  7   credits_tot        19054 non-null  float64
#  8   n_seme             19054 non-null  int64
#  9   years_since        19054 non-null  int64
#  10  college            19054 non-null  object
#  11  adm_unit           19054 non-null  int64
#  12  nation             19054 non-null  int64
#  13  in_capa            19054 non-null  bool
#  14  leave              19054 non-null  bool
# dtypes: bool(2), float64(3), int64(8), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Data Transformation

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

num_attrs = ['grade', 'gpa_last_seme', 'credits_last_seme', 'credits_tot', 'n_seme', 'years_since']
cat_attrs = ['semester', 'sex', 'adm_unit', 'nation', 'in_capa', 'college', 'leave']

full_pipeline = ColumnTransformer([
    ('num', StandardScaler(), num_attrs),
#    ('cat', 'passthrough', cat_attrs)
    ('cat', OneHotEncoder(), cat_attrs)
])

cat_pipeline = ColumnTransformer([
    ('num', StandardScaler(), num_attrs),
    ('cat', 'passthrough', cat_attrs)
])

X_t = full_pipeline.fit_transform(X_tr)
X_tr = pd.DataFrame(X_t, columns=full_pipeline.get_feature_names_out())

# %%
X_t = full_pipeline.transform(X_va)
X_va = pd.DataFrame(X_t, columns=full_pipeline.get_feature_names_out())

# %% [markdown]
# ## Model Training with Resampling

# %%
sampler_map = {
    "smote": SMOTE(random_state=0),
    "adasyn": ADASYN(
        sampling_strategy="auto",  # samples only the minority class
        random_state=0,  # for reproducibility
        n_neighbors=5,
    ),
    "cnn": CondensedNearestNeighbour(
        sampling_strategy="auto", random_state=0, n_neighbors=1, n_jobs=4
    ),
    "enn": EditedNearestNeighbours(
        sampling_strategy="auto", n_neighbors=3, kind_sel="all", n_jobs=4
    ),
    "tomek": TomekLinks(sampling_strategy="auto", n_jobs=4),
    "smoteenn": SMOTEENN(random_state=0),
}

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import StackingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_predict, cross_validate

cat_indices = [6, 7, 8, 9, 10, 11, 12]

estimators = [
    ('svm', SVC(C=10, gamma=0.1, random_state=42)),
    ('mlp', MLPClassifier(max_iter=10_000, hidden_layer_sizes=[10,10,10], random_state=42)),
    ('xgb', XGBClassifier(max_depth=4, n_estimators=70)),
    ('lgbm', LGBMClassifier(max_depth=8, n_estimators=100)),
    ('cat', CatBoostClassifier()),
]

# %%
stk = {}

for sampler in sampler_map.keys():
    print(sampler)
    X, y = sampler_map[sampler].fit_resample(X_tr, y_tr)

    # set up the classifier
    stk[sampler] = StackingClassifier(
        estimators=estimators, final_estimator=LogisticRegression(C=10)
    )

    stk[sampler].fit(X, y)
# Out:
# smote
# [LightGBM] [Info] Number of positive: 18069, number of negative: 18069
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003148 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7115
# [LightGBM] [Info] Number of data points in the train set: 36138, number of used features: 32
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Learning rate set to 0.047663
# 0:	learn: 0.6661290	total: 148ms	remaining: 2m 28s
# 1:	learn: 0.6371245	total: 154ms	remaining: 1m 16s
# 2:	learn: 0.6085822	total: 159ms	remaining: 52.9s
# 3:	learn: 0.5856289	total: 164ms	remaining: 40.9s
# 4:	learn: 0.5659193	total: 169ms	remaining: 33.7s
# 5:	learn: 0.5465709	total: 175ms	remaining: 29s
# 6:	learn: 0.5315232	total: 180ms	remaining: 25.6s
# 7:	learn: 0.5189778	total: 185ms	remaining: 23s
# 8:	learn: 0.5052216	total: 191ms	remaining: 21s
# 9:	learn: 0.4919320	total: 196ms	remaining: 19.4s
# 10:	learn: 0.4781808	total: 202ms	remaining: 18.1s
# 11:	learn: 0.4666829	total: 207ms	remaining: 17.1s
# 12:	learn: 0.4585191	total: 212ms	remaining: 16.1s
# 13:	learn: 0.4482328	total: 217ms	remaining: 15.3s
# 14:	learn: 0.4415734	total: 223ms	remaining: 14.6s
# 15:	learn: 0.4335955	total: 230ms	remaining: 14.1s
# 16:	learn: 0.4270468	total: 235ms	remaining: 13.6s
# 17:	learn: 0.4205088	total: 240ms	remaining: 13.1s
# 18:	learn: 0.4141196	total: 247ms	remaining: 12.7s
# 19:	learn: 0.4085019	total: 252ms	remaining: 12.4s
# 20:	learn: 0.4035860	total: 258ms	remaining: 12s
# 21:	learn: 0.3983909	total: 263ms	remaining: 11.7s
# 22:	learn: 0.3897689	total: 269ms	remaining: 11.4s
# 23:	learn: 0.3831453	total: 274ms	remaining: 11.2s
# 24:	learn: 0.3796955	total: 280ms	remaining: 10.9s
# 25:	learn: 0.3750198	total: 285ms	remaining: 10.7s
# 26:	learn: 0.3702151	total: 290ms	remaining: 10.5s
# 27:	learn: 0.3642168	total: 296ms	remaining: 10.3s
# 28:	learn: 0.3604421	total: 301ms	remaining: 10.1s
# 29:	learn: 0.3567588	total: 306ms	remaining: 9.9s
# 30:	learn: 0.3483443	total: 312ms	remaining: 9.74s
# 31:	learn: 0.3449894	total: 317ms	remaining: 9.59s
# 32:	learn: 0.3384026	total: 323ms	remaining: 9.46s
# 33:	learn: 0.3344764	total: 328ms	remaining: 9.32s
# 34:	learn: 0.3322793	total: 333ms	remaining: 9.19s
# 35:	learn: 0.3267096	total: 339ms	remaining: 9.08s
# 36:	learn: 0.3235753	total: 344ms	remaining: 8.96s
# 37:	learn: 0.3208338	total: 350ms	remaining: 8.85s
# 38:	learn: 0.3174413	total: 355ms	remaining: 8.74s
# 39:	learn: 0.3158122	total: 361ms	remaining: 8.65s
# 40:	learn: 0.3129102	total: 366ms	remaining: 8.56s
# 41:	learn: 0.3096172	total: 372ms	remaining: 8.48s
# 42:	learn: 0.3053825	total: 377ms	remaining: 8.4s
# 43:	learn: 0.3028545	total: 383ms	remaining: 8.31s
# 44:	learn: 0.3011682	total: 388ms	remaining: 8.23s
# 45:	learn: 0.2987835	total: 393ms	remaining: 8.15s
# 46:	learn: 0.2969985	total: 398ms	remaining: 8.08s
# 47:	learn: 0.2947711	total: 404ms	remaining: 8.01s
# 48:	learn: 0.2923072	total: 410ms	remaining: 7.96s
# 49:	learn: 0.2874294	total: 415ms	remaining: 7.89s
# 50:	learn: 0.2825517	total: 420ms	remaining: 7.82s
# 51:	learn: 0.2789368	total: 426ms	remaining: 7.76s
# 52:	learn: 0.2754232	total: 431ms	remaining: 7.7s
# 53:	learn: 0.2732072	total: 436ms	remaining: 7.64s
# 54:	learn: 0.2718267	total: 442ms	remaining: 7.59s
# 55:	learn: 0.2687719	total: 447ms	remaining: 7.54s
# 56:	learn: 0.2669826	total: 452ms	remaining: 7.48s
# 57:	learn: 0.2654235	total: 458ms	remaining: 7.43s
# 58:	learn: 0.2641721	total: 463ms	remaining: 7.38s
# 59:	learn: 0.2615348	total: 469ms	remaining: 7.34s
# 60:	learn: 0.2606019	total: 474ms	remaining: 7.29s
# 61:	learn: 0.2591412	total: 479ms	remaining: 7.25s
# 62:	learn: 0.2566502	total: 485ms	remaining: 7.21s
# 63:	learn: 0.2547415	total: 490ms	remaining: 7.17s
# 64:	learn: 0.2537709	total: 496ms	remaining: 7.13s
# 65:	learn: 0.2515405	total: 501ms	remaining: 7.09s
# 66:	learn: 0.2496093	total: 507ms	remaining: 7.06s
# 67:	learn: 0.2485368	total: 512ms	remaining: 7.02s
# 68:	learn: 0.2477786	total: 518ms	remaining: 6.98s
# 69:	learn: 0.2459402	total: 523ms	remaining: 6.95s
# 70:	learn: 0.2448452	total: 529ms	remaining: 6.92s
# 71:	learn: 0.2415814	total: 535ms	remaining: 6.89s
# 72:	learn: 0.2401658	total: 540ms	remaining: 6.86s
# 73:	learn: 0.2388639	total: 545ms	remaining: 6.83s
# 74:	learn: 0.2376276	total: 551ms	remaining: 6.8s
# 75:	learn: 0.2351406	total: 557ms	remaining: 6.77s
# 76:	learn: 0.2335627	total: 562ms	remaining: 6.73s
# 77:	learn: 0.2317752	total: 568ms	remaining: 6.71s
# 78:	learn: 0.2308096	total: 573ms	remaining: 6.68s
# 79:	learn: 0.2300031	total: 578ms	remaining: 6.65s
# 80:	learn: 0.2286345	total: 583ms	remaining: 6.62s
# 81:	learn: 0.2276890	total: 589ms	remaining: 6.6s
# 82:	learn: 0.2258195	total: 595ms	remaining: 6.57s
# 83:	learn: 0.2232809	total: 600ms	remaining: 6.54s
# 84:	learn: 0.2215354	total: 605ms	remaining: 6.52s
# 85:	learn: 0.2200435	total: 611ms	remaining: 6.49s
# 86:	learn: 0.2187374	total: 616ms	remaining: 6.47s
# 87:	learn: 0.2160573	total: 622ms	remaining: 6.45s
# 88:	learn: 0.2141954	total: 627ms	remaining: 6.42s
# 89:	learn: 0.2129715	total: 632ms	remaining: 6.39s
# 90:	learn: 0.2116294	total: 638ms	remaining: 6.37s
# 91:	learn: 0.2101853	total: 643ms	remaining: 6.35s
# 92:	learn: 0.2094873	total: 649ms	remaining: 6.33s
# 93:	learn: 0.2084076	total: 654ms	remaining: 6.31s
# 94:	learn: 0.2075321	total: 660ms	remaining: 6.29s
# 95:	learn: 0.2061827	total: 665ms	remaining: 6.27s
# 96:	learn: 0.2050275	total: 671ms	remaining: 6.25s
# 97:	learn: 0.2038835	total: 676ms	remaining: 6.22s
# 98:	learn: 0.2027922	total: 682ms	remaining: 6.21s
# 99:	learn: 0.2012040	total: 688ms	remaining: 6.19s
# 100:	learn: 0.2003772	total: 694ms	remaining: 6.17s
# 101:	learn: 0.1986668	total: 700ms	remaining: 6.16s
# 102:	learn: 0.1979989	total: 705ms	remaining: 6.14s
# 103:	learn: 0.1974537	total: 710ms	remaining: 6.12s
# 104:	learn: 0.1968693	total: 716ms	remaining: 6.1s
# 105:	learn: 0.1945529	total: 721ms	remaining: 6.08s
# 106:	learn: 0.1935345	total: 727ms	remaining: 6.06s
# 107:	learn: 0.1921380	total: 732ms	remaining: 6.04s
# 108:	learn: 0.1909804	total: 738ms	remaining: 6.03s
# 109:	learn: 0.1902462	total: 743ms	remaining: 6.01s
# 110:	learn: 0.1894205	total: 749ms	remaining: 6s
# 111:	learn: 0.1885448	total: 755ms	remaining: 5.98s
# 112:	learn: 0.1879302	total: 760ms	remaining: 5.97s
# 113:	learn: 0.1870781	total: 767ms	remaining: 5.96s
# 114:	learn: 0.1862506	total: 773ms	remaining: 5.95s
# 115:	learn: 0.1850926	total: 778ms	remaining: 5.93s
# 116:	learn: 0.1844738	total: 783ms	remaining: 5.91s
# 117:	learn: 0.1836834	total: 789ms	remaining: 5.89s
# 118:	learn: 0.1831609	total: 795ms	remaining: 5.89s
# 119:	learn: 0.1823971	total: 801ms	remaining: 5.87s
# 120:	learn: 0.1819941	total: 806ms	remaining: 5.85s
# 121:	learn: 0.1812752	total: 811ms	remaining: 5.84s
# 122:	learn: 0.1802881	total: 817ms	remaining: 5.83s
# 123:	learn: 0.1795224	total: 822ms	remaining: 5.81s
# 124:	learn: 0.1788348	total: 828ms	remaining: 5.79s
# 125:	learn: 0.1784146	total: 833ms	remaining: 5.78s
# 126:	learn: 0.1780458	total: 838ms	remaining: 5.76s
# 127:	learn: 0.1773438	total: 844ms	remaining: 5.75s
# 128:	learn: 0.1767686	total: 849ms	remaining: 5.73s
# 129:	learn: 0.1763799	total: 854ms	remaining: 5.72s
# 130:	learn: 0.1759228	total: 859ms	remaining: 5.7s
# 131:	learn: 0.1755122	total: 865ms	remaining: 5.69s
# 132:	learn: 0.1750241	total: 871ms	remaining: 5.68s
# 133:	learn: 0.1745252	total: 876ms	remaining: 5.66s
# 134:	learn: 0.1740128	total: 882ms	remaining: 5.65s
# 135:	learn: 0.1728791	total: 887ms	remaining: 5.63s
# 136:	learn: 0.1722499	total: 892ms	remaining: 5.62s
# 137:	learn: 0.1718983	total: 897ms	remaining: 5.61s
# 138:	learn: 0.1714334	total: 903ms	remaining: 5.59s
# 139:	learn: 0.1710357	total: 908ms	remaining: 5.58s
# 140:	learn: 0.1700394	total: 914ms	remaining: 5.57s
# 141:	learn: 0.1689187	total: 919ms	remaining: 5.55s
# 142:	learn: 0.1679689	total: 925ms	remaining: 5.54s
# 143:	learn: 0.1675608	total: 931ms	remaining: 5.53s
# 144:	learn: 0.1669600	total: 936ms	remaining: 5.52s
# 145:	learn: 0.1664030	total: 942ms	remaining: 5.51s
# 146:	learn: 0.1656791	total: 947ms	remaining: 5.5s
# 147:	learn: 0.1649326	total: 952ms	remaining: 5.48s
# 148:	learn: 0.1644889	total: 957ms	remaining: 5.47s
# 149:	learn: 0.1639907	total: 963ms	remaining: 5.46s
# 150:	learn: 0.1636202	total: 969ms	remaining: 5.45s
# 151:	learn: 0.1631491	total: 974ms	remaining: 5.43s
# 152:	learn: 0.1627974	total: 979ms	remaining: 5.42s
# 153:	learn: 0.1625413	total: 984ms	remaining: 5.41s
# 154:	learn: 0.1620412	total: 989ms	remaining: 5.39s
# 155:	learn: 0.1616329	total: 995ms	remaining: 5.38s
# 156:	learn: 0.1614078	total: 999ms	remaining: 5.37s
# 157:	learn: 0.1609317	total: 1s	remaining: 5.35s
# 158:	learn: 0.1605871	total: 1.01s	remaining: 5.34s
# 159:	learn: 0.1597951	total: 1.01s	remaining: 5.33s
# 160:	learn: 0.1594880	total: 1.02s	remaining: 5.32s
# 161:	learn: 0.1591522	total: 1.02s	remaining: 5.31s
# 162:	learn: 0.1589854	total: 1.03s	remaining: 5.29s
# 163:	learn: 0.1584597	total: 1.04s	remaining: 5.28s
# 164:	learn: 0.1578754	total: 1.04s	remaining: 5.27s
# 165:	learn: 0.1576608	total: 1.05s	remaining: 5.26s
# 166:	learn: 0.1571461	total: 1.05s	remaining: 5.25s
# 167:	learn: 0.1563898	total: 1.06s	remaining: 5.23s
# 168:	learn: 0.1560745	total: 1.06s	remaining: 5.22s
# 169:	learn: 0.1557798	total: 1.07s	remaining: 5.21s
# 170:	learn: 0.1550183	total: 1.07s	remaining: 5.2s
# 171:	learn: 0.1547430	total: 1.08s	remaining: 5.19s
# 172:	learn: 0.1543129	total: 1.08s	remaining: 5.18s
# 173:	learn: 0.1539206	total: 1.09s	remaining: 5.17s
# 174:	learn: 0.1535992	total: 1.09s	remaining: 5.16s
# 175:	learn: 0.1533441	total: 1.1s	remaining: 5.15s
# 176:	learn: 0.1530021	total: 1.1s	remaining: 5.14s
# 177:	learn: 0.1526238	total: 1.11s	remaining: 5.13s
# 178:	learn: 0.1521601	total: 1.11s	remaining: 5.12s
# 179:	learn: 0.1519010	total: 1.12s	remaining: 5.11s
# 180:	learn: 0.1511762	total: 1.13s	remaining: 5.1s
# 181:	learn: 0.1507340	total: 1.13s	remaining: 5.09s
# 182:	learn: 0.1500044	total: 1.14s	remaining: 5.08s
# 183:	learn: 0.1496591	total: 1.14s	remaining: 5.07s
# 184:	learn: 0.1493598	total: 1.15s	remaining: 5.05s
# 185:	learn: 0.1489968	total: 1.15s	remaining: 5.04s
# 186:	learn: 0.1486967	total: 1.16s	remaining: 5.03s
# 187:	learn: 0.1480037	total: 1.16s	remaining: 5.02s
# 188:	learn: 0.1476236	total: 1.17s	remaining: 5.01s
# 189:	learn: 0.1471179	total: 1.17s	remaining: 5s
# 190:	learn: 0.1466972	total: 1.18s	remaining: 4.99s
# 191:	learn: 0.1460724	total: 1.18s	remaining: 4.98s
# 192:	learn: 0.1458738	total: 1.19s	remaining: 4.98s
# 193:	learn: 0.1456111	total: 1.2s	remaining: 4.97s
# 194:	learn: 0.1454533	total: 1.2s	remaining: 4.96s
# 195:	learn: 0.1449871	total: 1.21s	remaining: 4.96s
# 196:	learn: 0.1445080	total: 1.21s	remaining: 4.95s
# 197:	learn: 0.1440958	total: 1.22s	remaining: 4.94s
# 198:	learn: 0.1436459	total: 1.22s	remaining: 4.93s
# 199:	learn: 0.1433177	total: 1.23s	remaining: 4.92s
# 200:	learn: 0.1428310	total: 1.24s	remaining: 4.91s
# 201:	learn: 0.1425268	total: 1.24s	remaining: 4.9s
# 202:	learn: 0.1421745	total: 1.25s	remaining: 4.89s
# 203:	learn: 0.1419534	total: 1.25s	remaining: 4.88s
# 204:	learn: 0.1416189	total: 1.26s	remaining: 4.87s
# 205:	learn: 0.1414442	total: 1.26s	remaining: 4.86s
# 206:	learn: 0.1411930	total: 1.27s	remaining: 4.85s
# 207:	learn: 0.1408589	total: 1.27s	remaining: 4.84s
# 208:	learn: 0.1406968	total: 1.28s	remaining: 4.83s
# 209:	learn: 0.1402510	total: 1.28s	remaining: 4.82s
# 210:	learn: 0.1399772	total: 1.29s	remaining: 4.82s
# 211:	learn: 0.1397044	total: 1.29s	remaining: 4.8s
# 212:	learn: 0.1392167	total: 1.3s	remaining: 4.79s
# 213:	learn: 0.1389064	total: 1.3s	remaining: 4.79s
# 214:	learn: 0.1385024	total: 1.31s	remaining: 4.78s
# 215:	learn: 0.1381733	total: 1.31s	remaining: 4.77s
# 216:	learn: 0.1372667	total: 1.32s	remaining: 4.76s
# 217:	learn: 0.1371054	total: 1.32s	remaining: 4.75s
# 218:	learn: 0.1364350	total: 1.33s	remaining: 4.74s
# 219:	learn: 0.1362112	total: 1.33s	remaining: 4.74s
# 220:	learn: 0.1361066	total: 1.34s	remaining: 4.73s
# 221:	learn: 0.1358763	total: 1.35s	remaining: 4.72s
# 222:	learn: 0.1356076	total: 1.35s	remaining: 4.71s
# 223:	learn: 0.1353310	total: 1.36s	remaining: 4.7s
# 224:	learn: 0.1350722	total: 1.36s	remaining: 4.7s
# 225:	learn: 0.1346263	total: 1.37s	remaining: 4.69s
# 226:	learn: 0.1341931	total: 1.37s	remaining: 4.68s
# 227:	learn: 0.1340628	total: 1.38s	remaining: 4.67s
# 228:	learn: 0.1335397	total: 1.39s	remaining: 4.66s
# 229:	learn: 0.1331997	total: 1.39s	remaining: 4.65s
# 230:	learn: 0.1329775	total: 1.4s	remaining: 4.64s
# 231:	learn: 0.1327708	total: 1.4s	remaining: 4.63s
# 232:	learn: 0.1322429	total: 1.41s	remaining: 4.63s
# 233:	learn: 0.1317719	total: 1.41s	remaining: 4.62s
# 234:	learn: 0.1315902	total: 1.42s	remaining: 4.61s
# 235:	learn: 0.1309588	total: 1.42s	remaining: 4.6s
# 236:	learn: 0.1304947	total: 1.43s	remaining: 4.59s
# 237:	learn: 0.1302363	total: 1.43s	remaining: 4.58s
# 238:	learn: 0.1298547	total: 1.44s	remaining: 4.57s
# 239:	learn: 0.1290191	total: 1.44s	remaining: 4.56s
# 240:	learn: 0.1287822	total: 1.45s	remaining: 4.55s
# 241:	learn: 0.1286323	total: 1.45s	remaining: 4.55s
# 242:	learn: 0.1282564	total: 1.46s	remaining: 4.54s
# 243:	learn: 0.1280284	total: 1.46s	remaining: 4.53s
# 244:	learn: 0.1277129	total: 1.47s	remaining: 4.52s
# 245:	learn: 0.1275158	total: 1.47s	remaining: 4.51s
# 246:	learn: 0.1270980	total: 1.48s	remaining: 4.5s
# 247:	learn: 0.1268418	total: 1.48s	remaining: 4.5s
# 248:	learn: 0.1266721	total: 1.49s	remaining: 4.49s
# 249:	learn: 0.1265187	total: 1.49s	remaining: 4.48s
# 250:	learn: 0.1262553	total: 1.5s	remaining: 4.47s
# 251:	learn: 0.1261240	total: 1.5s	remaining: 4.46s
# 252:	learn: 0.1259080	total: 1.51s	remaining: 4.46s
# 253:	learn: 0.1255304	total: 1.51s	remaining: 4.45s
# 254:	learn: 0.1252071	total: 1.52s	remaining: 4.44s
# 255:	learn: 0.1245964	total: 1.53s	remaining: 4.44s
# 256:	learn: 0.1244280	total: 1.53s	remaining: 4.43s
# 257:	learn: 0.1242474	total: 1.54s	remaining: 4.42s
# 258:	learn: 0.1239263	total: 1.54s	remaining: 4.41s
# 259:	learn: 0.1237684	total: 1.55s	remaining: 4.4s
# 260:	learn: 0.1231703	total: 1.55s	remaining: 4.39s
# 261:	learn: 0.1226201	total: 1.56s	remaining: 4.39s
# 262:	learn: 0.1217808	total: 1.56s	remaining: 4.38s
# 263:	learn: 0.1215027	total: 1.57s	remaining: 4.37s
# 264:	learn: 0.1211994	total: 1.57s	remaining: 4.36s
# 265:	learn: 0.1209558	total: 1.58s	remaining: 4.35s
# 266:	learn: 0.1207084	total: 1.58s	remaining: 4.35s
# 267:	learn: 0.1199535	total: 1.59s	remaining: 4.34s
# 268:	learn: 0.1196052	total: 1.59s	remaining: 4.33s
# 269:	learn: 0.1192826	total: 1.6s	remaining: 4.32s
# 270:	learn: 0.1190349	total: 1.6s	remaining: 4.32s
# 271:	learn: 0.1186561	total: 1.61s	remaining: 4.31s
# 272:	learn: 0.1179711	total: 1.61s	remaining: 4.3s
# 273:	learn: 0.1177607	total: 1.62s	remaining: 4.29s
# 274:	learn: 0.1175819	total: 1.62s	remaining: 4.28s
# 275:	learn: 0.1172564	total: 1.63s	remaining: 4.28s
# 276:	learn: 0.1167232	total: 1.64s	remaining: 4.27s
# 277:	learn: 0.1165144	total: 1.64s	remaining: 4.27s
# 278:	learn: 0.1159291	total: 1.65s	remaining: 4.26s
# 279:	learn: 0.1151451	total: 1.65s	remaining: 4.25s
# 280:	learn: 0.1149477	total: 1.66s	remaining: 4.24s
# 281:	learn: 0.1146276	total: 1.66s	remaining: 4.24s
# 282:	learn: 0.1142523	total: 1.67s	remaining: 4.23s
# 283:	learn: 0.1141011	total: 1.68s	remaining: 4.22s
# 284:	learn: 0.1140052	total: 1.68s	remaining: 4.21s
# 285:	learn: 0.1137525	total: 1.69s	remaining: 4.21s
# 286:	learn: 0.1135612	total: 1.69s	remaining: 4.2s
# 287:	learn: 0.1134103	total: 1.7s	remaining: 4.19s
# 288:	learn: 0.1132142	total: 1.7s	remaining: 4.19s
# 289:	learn: 0.1130354	total: 1.71s	remaining: 4.18s
# 290:	learn: 0.1129055	total: 1.71s	remaining: 4.17s
# 291:	learn: 0.1127291	total: 1.72s	remaining: 4.17s
# 292:	learn: 0.1122656	total: 1.72s	remaining: 4.16s
# 293:	learn: 0.1121324	total: 1.73s	remaining: 4.15s
# 294:	learn: 0.1117115	total: 1.73s	remaining: 4.14s
# 295:	learn: 0.1116210	total: 1.74s	remaining: 4.14s
# 296:	learn: 0.1112110	total: 1.75s	remaining: 4.13s
# 297:	learn: 0.1110806	total: 1.75s	remaining: 4.13s
# 298:	learn: 0.1108346	total: 1.76s	remaining: 4.12s
# 299:	learn: 0.1106974	total: 1.76s	remaining: 4.12s
# 300:	learn: 0.1103796	total: 1.77s	remaining: 4.11s
# 301:	learn: 0.1102294	total: 1.77s	remaining: 4.1s
# 302:	learn: 0.1101062	total: 1.78s	remaining: 4.1s
# 303:	learn: 0.1099423	total: 1.79s	remaining: 4.09s
# 304:	learn: 0.1097928	total: 1.79s	remaining: 4.08s
# 305:	learn: 0.1096024	total: 1.8s	remaining: 4.08s
# 306:	learn: 0.1095199	total: 1.8s	remaining: 4.07s
# 307:	learn: 0.1089838	total: 1.81s	remaining: 4.06s
# 308:	learn: 0.1088528	total: 1.81s	remaining: 4.05s
# 309:	learn: 0.1086315	total: 1.82s	remaining: 4.05s
# 310:	learn: 0.1084830	total: 1.82s	remaining: 4.04s
# 311:	learn: 0.1082905	total: 1.83s	remaining: 4.04s
# 312:	learn: 0.1081973	total: 1.83s	remaining: 4.03s
# 313:	learn: 0.1080718	total: 1.84s	remaining: 4.02s
# 314:	learn: 0.1079698	total: 1.84s	remaining: 4.01s
# 315:	learn: 0.1078607	total: 1.85s	remaining: 4.01s
# 316:	learn: 0.1076925	total: 1.86s	remaining: 4s
# 317:	learn: 0.1075750	total: 1.86s	remaining: 3.99s
# 318:	learn: 0.1074147	total: 1.87s	remaining: 3.98s
# 319:	learn: 0.1073220	total: 1.87s	remaining: 3.98s
# 320:	learn: 0.1071452	total: 1.88s	remaining: 3.97s
# 321:	learn: 0.1070146	total: 1.88s	remaining: 3.97s
# 322:	learn: 0.1066633	total: 1.89s	remaining: 3.96s
# 323:	learn: 0.1063657	total: 1.9s	remaining: 3.95s
# 324:	learn: 0.1060476	total: 1.9s	remaining: 3.95s
# 325:	learn: 0.1058923	total: 1.91s	remaining: 3.94s
# 326:	learn: 0.1057234	total: 1.91s	remaining: 3.93s
# 327:	learn: 0.1055687	total: 1.92s	remaining: 3.93s
# 328:	learn: 0.1052734	total: 1.92s	remaining: 3.92s
# 329:	learn: 0.1050917	total: 1.93s	remaining: 3.91s
# 330:	learn: 0.1048692	total: 1.93s	remaining: 3.9s
# 331:	learn: 0.1046798	total: 1.94s	remaining: 3.9s
# 332:	learn: 0.1045345	total: 1.94s	remaining: 3.89s
# 333:	learn: 0.1043221	total: 1.95s	remaining: 3.88s
# 334:	learn: 0.1042177	total: 1.95s	remaining: 3.88s
# 335:	learn: 0.1041147	total: 1.96s	remaining: 3.87s
# 336:	learn: 0.1039384	total: 1.96s	remaining: 3.86s
# 337:	learn: 0.1037697	total: 1.97s	remaining: 3.86s
# 338:	learn: 0.1035994	total: 1.97s	remaining: 3.85s
# 339:	learn: 0.1034754	total: 1.98s	remaining: 3.84s
# 340:	learn: 0.1034124	total: 1.98s	remaining: 3.83s
# 341:	learn: 0.1033089	total: 1.99s	remaining: 3.83s
# 342:	learn: 0.1031987	total: 1.99s	remaining: 3.82s
# 343:	learn: 0.1029881	total: 2s	remaining: 3.81s
# 344:	learn: 0.1028297	total: 2s	remaining: 3.81s
# 345:	learn: 0.1027721	total: 2.01s	remaining: 3.8s
# 346:	learn: 0.1026969	total: 2.02s	remaining: 3.79s
# 347:	learn: 0.1024101	total: 2.02s	remaining: 3.79s
# 348:	learn: 0.1022851	total: 2.03s	remaining: 3.78s
# 349:	learn: 0.1022047	total: 2.03s	remaining: 3.78s
# 350:	learn: 0.1020978	total: 2.04s	remaining: 3.77s
# 351:	learn: 0.1019529	total: 2.04s	remaining: 3.76s
# 352:	learn: 0.1017595	total: 2.05s	remaining: 3.76s
# 353:	learn: 0.1013547	total: 2.06s	remaining: 3.75s
# 354:	learn: 0.1010875	total: 2.06s	remaining: 3.75s
# 355:	learn: 0.1009791	total: 2.07s	remaining: 3.74s
# 356:	learn: 0.1008549	total: 2.07s	remaining: 3.73s
# 357:	learn: 0.1006998	total: 2.08s	remaining: 3.72s
# 358:	learn: 0.1005716	total: 2.08s	remaining: 3.72s
# 359:	learn: 0.1003738	total: 2.09s	remaining: 3.71s
# 360:	learn: 0.1002297	total: 2.09s	remaining: 3.7s
# 361:	learn: 0.1001482	total: 2.1s	remaining: 3.7s
# 362:	learn: 0.1000822	total: 2.1s	remaining: 3.69s
# 363:	learn: 0.1000129	total: 2.11s	remaining: 3.68s
# 364:	learn: 0.0998855	total: 2.11s	remaining: 3.67s
# 365:	learn: 0.0998097	total: 2.12s	remaining: 3.67s
# 366:	learn: 0.0996554	total: 2.12s	remaining: 3.66s
# 367:	learn: 0.0995729	total: 2.13s	remaining: 3.65s
# 368:	learn: 0.0995049	total: 2.13s	remaining: 3.65s
# 369:	learn: 0.0993703	total: 2.14s	remaining: 3.64s
# 370:	learn: 0.0992974	total: 2.14s	remaining: 3.63s
# 371:	learn: 0.0990416	total: 2.15s	remaining: 3.63s
# 372:	learn: 0.0989174	total: 2.15s	remaining: 3.62s
# 373:	learn: 0.0988259	total: 2.16s	remaining: 3.61s
# 374:	learn: 0.0987448	total: 2.16s	remaining: 3.61s
# 375:	learn: 0.0986546	total: 2.17s	remaining: 3.6s
# 376:	learn: 0.0985702	total: 2.17s	remaining: 3.59s
# 377:	learn: 0.0984464	total: 2.18s	remaining: 3.59s
# 378:	learn: 0.0983148	total: 2.18s	remaining: 3.58s
# 379:	learn: 0.0982311	total: 2.19s	remaining: 3.57s
# 380:	learn: 0.0981497	total: 2.19s	remaining: 3.57s
# 381:	learn: 0.0980586	total: 2.2s	remaining: 3.56s
# 382:	learn: 0.0979611	total: 2.21s	remaining: 3.55s
# 383:	learn: 0.0979011	total: 2.21s	remaining: 3.55s
# 384:	learn: 0.0977616	total: 2.22s	remaining: 3.54s
# 385:	learn: 0.0976429	total: 2.22s	remaining: 3.54s
# 386:	learn: 0.0975710	total: 2.23s	remaining: 3.53s
# 387:	learn: 0.0974303	total: 2.23s	remaining: 3.52s
# 388:	learn: 0.0973507	total: 2.24s	remaining: 3.52s
# 389:	learn: 0.0972798	total: 2.25s	remaining: 3.51s
# 390:	learn: 0.0970943	total: 2.25s	remaining: 3.51s
# 391:	learn: 0.0966449	total: 2.26s	remaining: 3.5s
# 392:	learn: 0.0963922	total: 2.26s	remaining: 3.49s
# 393:	learn: 0.0961815	total: 2.27s	remaining: 3.49s
# 394:	learn: 0.0960853	total: 2.27s	remaining: 3.48s
# 395:	learn: 0.0959346	total: 2.28s	remaining: 3.48s
# 396:	learn: 0.0958126	total: 2.28s	remaining: 3.47s
# 397:	learn: 0.0956067	total: 2.29s	remaining: 3.46s
# 398:	learn: 0.0955148	total: 2.29s	remaining: 3.46s
# 399:	learn: 0.0954464	total: 2.3s	remaining: 3.45s
# 400:	learn: 0.0952523	total: 2.3s	remaining: 3.44s
# 401:	learn: 0.0951879	total: 2.31s	remaining: 3.44s
# 402:	learn: 0.0951215	total: 2.31s	remaining: 3.43s
# 403:	learn: 0.0950380	total: 2.32s	remaining: 3.42s
# 404:	learn: 0.0948369	total: 2.33s	remaining: 3.42s
# 405:	learn: 0.0946959	total: 2.33s	remaining: 3.41s
# 406:	learn: 0.0944959	total: 2.33s	remaining: 3.4s
# 407:	learn: 0.0943573	total: 2.34s	remaining: 3.4s
# 408:	learn: 0.0943054	total: 2.35s	remaining: 3.39s
# 409:	learn: 0.0941970	total: 2.35s	remaining: 3.38s
# 410:	learn: 0.0940861	total: 2.35s	remaining: 3.38s
# 411:	learn: 0.0939031	total: 2.36s	remaining: 3.37s
# 412:	learn: 0.0938253	total: 2.37s	remaining: 3.36s
# 413:	learn: 0.0937391	total: 2.37s	remaining: 3.35s
# 414:	learn: 0.0936006	total: 2.38s	remaining: 3.35s
# 415:	learn: 0.0934704	total: 2.38s	remaining: 3.34s
# 416:	learn: 0.0933750	total: 2.39s	remaining: 3.33s
# 417:	learn: 0.0932513	total: 2.39s	remaining: 3.33s
# 418:	learn: 0.0931564	total: 2.4s	remaining: 3.32s
# 419:	learn: 0.0930792	total: 2.4s	remaining: 3.32s
# 420:	learn: 0.0930124	total: 2.41s	remaining: 3.31s
# 421:	learn: 0.0928070	total: 2.41s	remaining: 3.3s
# 422:	learn: 0.0927144	total: 2.42s	remaining: 3.3s
# 423:	learn: 0.0925801	total: 2.42s	remaining: 3.29s
# 424:	learn: 0.0924324	total: 2.43s	remaining: 3.28s
# 425:	learn: 0.0922777	total: 2.43s	remaining: 3.28s
# 426:	learn: 0.0921717	total: 2.44s	remaining: 3.27s
# 427:	learn: 0.0921096	total: 2.44s	remaining: 3.27s
# 428:	learn: 0.0920510	total: 2.45s	remaining: 3.26s
# 429:	learn: 0.0919466	total: 2.45s	remaining: 3.25s
# 430:	learn: 0.0917675	total: 2.46s	remaining: 3.25s
# 431:	learn: 0.0916480	total: 2.46s	remaining: 3.24s
# 432:	learn: 0.0915981	total: 2.47s	remaining: 3.23s
# 433:	learn: 0.0914872	total: 2.47s	remaining: 3.23s
# 434:	learn: 0.0913768	total: 2.48s	remaining: 3.22s
# 435:	learn: 0.0913288	total: 2.48s	remaining: 3.21s
# 436:	learn: 0.0912438	total: 2.49s	remaining: 3.21s
# 437:	learn: 0.0911089	total: 2.5s	remaining: 3.2s
# 438:	learn: 0.0910774	total: 2.5s	remaining: 3.19s
# 439:	learn: 0.0909457	total: 2.51s	remaining: 3.19s
# 440:	learn: 0.0907651	total: 2.51s	remaining: 3.18s
# 441:	learn: 0.0906066	total: 2.52s	remaining: 3.18s
# 442:	learn: 0.0905149	total: 2.52s	remaining: 3.17s
# 443:	learn: 0.0904479	total: 2.53s	remaining: 3.16s
# 444:	learn: 0.0903300	total: 2.53s	remaining: 3.16s
# 445:	learn: 0.0902614	total: 2.54s	remaining: 3.15s
# 446:	learn: 0.0901909	total: 2.54s	remaining: 3.15s
# 447:	learn: 0.0900535	total: 2.55s	remaining: 3.14s
# 448:	learn: 0.0899607	total: 2.55s	remaining: 3.13s
# 449:	learn: 0.0898353	total: 2.56s	remaining: 3.13s
# 450:	learn: 0.0896912	total: 2.56s	remaining: 3.12s
# 451:	learn: 0.0895934	total: 2.57s	remaining: 3.11s
# 452:	learn: 0.0894709	total: 2.57s	remaining: 3.11s
# 453:	learn: 0.0894083	total: 2.58s	remaining: 3.1s
# 454:	learn: 0.0893684	total: 2.58s	remaining: 3.1s
# 455:	learn: 0.0893053	total: 2.59s	remaining: 3.09s
# 456:	learn: 0.0892280	total: 2.59s	remaining: 3.08s
# 457:	learn: 0.0891558	total: 2.6s	remaining: 3.08s
# 458:	learn: 0.0891192	total: 2.6s	remaining: 3.07s
# 459:	learn: 0.0890789	total: 2.61s	remaining: 3.06s
# 460:	learn: 0.0888822	total: 2.62s	remaining: 3.06s
# 461:	learn: 0.0887771	total: 2.62s	remaining: 3.05s
# 462:	learn: 0.0886709	total: 2.63s	remaining: 3.05s
# 463:	learn: 0.0885486	total: 2.63s	remaining: 3.04s
# 464:	learn: 0.0884681	total: 2.64s	remaining: 3.04s
# 465:	learn: 0.0883232	total: 2.64s	remaining: 3.03s
# 466:	learn: 0.0882386	total: 2.65s	remaining: 3.02s
# 467:	learn: 0.0881076	total: 2.65s	remaining: 3.02s
# 468:	learn: 0.0880404	total: 2.66s	remaining: 3.01s
# 469:	learn: 0.0879589	total: 2.67s	remaining: 3s
# 470:	learn: 0.0878640	total: 2.67s	remaining: 3s
# 471:	learn: 0.0878111	total: 2.67s	remaining: 2.99s
# 472:	learn: 0.0877187	total: 2.68s	remaining: 2.99s
# 473:	learn: 0.0876519	total: 2.69s	remaining: 2.98s
# 474:	learn: 0.0875462	total: 2.69s	remaining: 2.98s
# 475:	learn: 0.0874911	total: 2.7s	remaining: 2.97s
# 476:	learn: 0.0874180	total: 2.7s	remaining: 2.96s
# 477:	learn: 0.0873338	total: 2.71s	remaining: 2.96s
# 478:	learn: 0.0872395	total: 2.71s	remaining: 2.95s
# 479:	learn: 0.0871840	total: 2.72s	remaining: 2.94s
# 480:	learn: 0.0871241	total: 2.72s	remaining: 2.94s
# 481:	learn: 0.0870033	total: 2.73s	remaining: 2.93s
# 482:	learn: 0.0869158	total: 2.73s	remaining: 2.92s
# 483:	learn: 0.0868597	total: 2.74s	remaining: 2.92s
# 484:	learn: 0.0867995	total: 2.74s	remaining: 2.91s
# 485:	learn: 0.0867097	total: 2.75s	remaining: 2.91s
# 486:	learn: 0.0866426	total: 2.75s	remaining: 2.9s
# 487:	learn: 0.0865801	total: 2.76s	remaining: 2.89s
# 488:	learn: 0.0865460	total: 2.76s	remaining: 2.89s
# 489:	learn: 0.0864824	total: 2.77s	remaining: 2.88s
# 490:	learn: 0.0863176	total: 2.77s	remaining: 2.88s
# 491:	learn: 0.0862464	total: 2.78s	remaining: 2.87s
# 492:	learn: 0.0861587	total: 2.78s	remaining: 2.86s
# 493:	learn: 0.0861003	total: 2.79s	remaining: 2.86s
# 494:	learn: 0.0860583	total: 2.79s	remaining: 2.85s
# 495:	learn: 0.0859757	total: 2.8s	remaining: 2.84s
# 496:	learn: 0.0858260	total: 2.8s	remaining: 2.84s
# 497:	learn: 0.0856994	total: 2.81s	remaining: 2.83s
# 498:	learn: 0.0855958	total: 2.81s	remaining: 2.83s
# 499:	learn: 0.0855122	total: 2.82s	remaining: 2.82s
# 500:	learn: 0.0853772	total: 2.83s	remaining: 2.81s
# 501:	learn: 0.0852751	total: 2.83s	remaining: 2.81s
# 502:	learn: 0.0851988	total: 2.84s	remaining: 2.8s
# 503:	learn: 0.0850559	total: 2.84s	remaining: 2.8s
# 504:	learn: 0.0849755	total: 2.85s	remaining: 2.79s
# 505:	learn: 0.0849179	total: 2.85s	remaining: 2.78s
# 506:	learn: 0.0848346	total: 2.86s	remaining: 2.78s
# 507:	learn: 0.0847433	total: 2.86s	remaining: 2.77s
# 508:	learn: 0.0846722	total: 2.87s	remaining: 2.77s
# 509:	learn: 0.0846032	total: 2.87s	remaining: 2.76s
# 510:	learn: 0.0844982	total: 2.88s	remaining: 2.75s
# 511:	learn: 0.0844100	total: 2.88s	remaining: 2.75s
# 512:	learn: 0.0843636	total: 2.89s	remaining: 2.74s
# 513:	learn: 0.0842882	total: 2.89s	remaining: 2.74s
# 514:	learn: 0.0841802	total: 2.9s	remaining: 2.73s
# 515:	learn: 0.0840948	total: 2.9s	remaining: 2.72s
# 516:	learn: 0.0840148	total: 2.91s	remaining: 2.72s
# 517:	learn: 0.0839904	total: 2.91s	remaining: 2.71s
# 518:	learn: 0.0839503	total: 2.92s	remaining: 2.71s
# 519:	learn: 0.0838837	total: 2.92s	remaining: 2.7s
# 520:	learn: 0.0838400	total: 2.93s	remaining: 2.69s
# 521:	learn: 0.0837257	total: 2.93s	remaining: 2.69s
# 522:	learn: 0.0836559	total: 2.94s	remaining: 2.68s
# 523:	learn: 0.0835558	total: 2.94s	remaining: 2.67s
# 524:	learn: 0.0834717	total: 2.95s	remaining: 2.67s
# 525:	learn: 0.0833729	total: 2.95s	remaining: 2.66s
# 526:	learn: 0.0833127	total: 2.96s	remaining: 2.66s
# 527:	learn: 0.0832392	total: 2.96s	remaining: 2.65s
# 528:	learn: 0.0831549	total: 2.97s	remaining: 2.64s
# 529:	learn: 0.0830911	total: 2.98s	remaining: 2.64s
# 530:	learn: 0.0829640	total: 2.98s	remaining: 2.63s
# 531:	learn: 0.0827819	total: 2.99s	remaining: 2.63s
# 532:	learn: 0.0827185	total: 2.99s	remaining: 2.62s
# 533:	learn: 0.0826290	total: 3s	remaining: 2.62s
# 534:	learn: 0.0825880	total: 3s	remaining: 2.61s
# 535:	learn: 0.0825552	total: 3.01s	remaining: 2.6s
# 536:	learn: 0.0825134	total: 3.01s	remaining: 2.6s
# 537:	learn: 0.0824254	total: 3.02s	remaining: 2.59s
# 538:	learn: 0.0823436	total: 3.02s	remaining: 2.59s
# 539:	learn: 0.0822655	total: 3.03s	remaining: 2.58s
# 540:	learn: 0.0822044	total: 3.03s	remaining: 2.57s
# 541:	learn: 0.0821261	total: 3.04s	remaining: 2.57s
# 542:	learn: 0.0821025	total: 3.04s	remaining: 2.56s
# 543:	learn: 0.0820647	total: 3.05s	remaining: 2.56s
# 544:	learn: 0.0820078	total: 3.06s	remaining: 2.55s
# 545:	learn: 0.0819177	total: 3.06s	remaining: 2.54s
# 546:	learn: 0.0818393	total: 3.07s	remaining: 2.54s
# 547:	learn: 0.0817680	total: 3.07s	remaining: 2.53s
# 548:	learn: 0.0817142	total: 3.08s	remaining: 2.53s
# 549:	learn: 0.0816632	total: 3.08s	remaining: 2.52s
# 550:	learn: 0.0816140	total: 3.09s	remaining: 2.52s
# 551:	learn: 0.0815522	total: 3.09s	remaining: 2.51s
# 552:	learn: 0.0815282	total: 3.1s	remaining: 2.5s
# 553:	learn: 0.0813959	total: 3.1s	remaining: 2.5s
# 554:	learn: 0.0813346	total: 3.11s	remaining: 2.49s
# 555:	learn: 0.0812717	total: 3.11s	remaining: 2.49s
# 556:	learn: 0.0812199	total: 3.12s	remaining: 2.48s
# 557:	learn: 0.0811680	total: 3.12s	remaining: 2.47s
# 558:	learn: 0.0811101	total: 3.13s	remaining: 2.47s
# 559:	learn: 0.0810523	total: 3.13s	remaining: 2.46s
# 560:	learn: 0.0809971	total: 3.14s	remaining: 2.46s
# 561:	learn: 0.0809392	total: 3.14s	remaining: 2.45s
# 562:	learn: 0.0808336	total: 3.15s	remaining: 2.44s
# 563:	learn: 0.0807486	total: 3.15s	remaining: 2.44s
# 564:	learn: 0.0807161	total: 3.16s	remaining: 2.43s
# 565:	learn: 0.0806594	total: 3.16s	remaining: 2.42s
# 566:	learn: 0.0805165	total: 3.17s	remaining: 2.42s
# 567:	learn: 0.0804573	total: 3.17s	remaining: 2.41s
# 568:	learn: 0.0804024	total: 3.18s	remaining: 2.41s
# 569:	learn: 0.0803265	total: 3.18s	remaining: 2.4s
# 570:	learn: 0.0802956	total: 3.19s	remaining: 2.4s
# 571:	learn: 0.0802487	total: 3.19s	remaining: 2.39s
# 572:	learn: 0.0801377	total: 3.2s	remaining: 2.38s
# 573:	learn: 0.0801016	total: 3.2s	remaining: 2.38s
# 574:	learn: 0.0800586	total: 3.21s	remaining: 2.37s
# 575:	learn: 0.0800072	total: 3.21s	remaining: 2.37s
# 576:	learn: 0.0799732	total: 3.22s	remaining: 2.36s
# 577:	learn: 0.0799218	total: 3.23s	remaining: 2.35s
# 578:	learn: 0.0798100	total: 3.23s	remaining: 2.35s
# 579:	learn: 0.0797592	total: 3.24s	remaining: 2.34s
# 580:	learn: 0.0797217	total: 3.24s	remaining: 2.34s
# 581:	learn: 0.0796726	total: 3.25s	remaining: 2.33s
# 582:	learn: 0.0796137	total: 3.25s	remaining: 2.33s
# 583:	learn: 0.0795109	total: 3.26s	remaining: 2.32s
# 584:	learn: 0.0794639	total: 3.26s	remaining: 2.31s
# 585:	learn: 0.0794247	total: 3.27s	remaining: 2.31s
# 586:	learn: 0.0793943	total: 3.27s	remaining: 2.3s
# 587:	learn: 0.0792928	total: 3.28s	remaining: 2.3s
# 588:	learn: 0.0792442	total: 3.29s	remaining: 2.29s
# 589:	learn: 0.0792235	total: 3.29s	remaining: 2.29s
# 590:	learn: 0.0791548	total: 3.29s	remaining: 2.28s
# 591:	learn: 0.0791181	total: 3.3s	remaining: 2.27s
# 592:	learn: 0.0790382	total: 3.31s	remaining: 2.27s
# 593:	learn: 0.0789348	total: 3.31s	remaining: 2.26s
# 594:	learn: 0.0788757	total: 3.32s	remaining: 2.26s
# 595:	learn: 0.0788560	total: 3.32s	remaining: 2.25s
# 596:	learn: 0.0788221	total: 3.33s	remaining: 2.25s
# 597:	learn: 0.0787323	total: 3.33s	remaining: 2.24s
# 598:	learn: 0.0787047	total: 3.34s	remaining: 2.23s
# 599:	learn: 0.0786477	total: 3.35s	remaining: 2.23s
# 600:	learn: 0.0785996	total: 3.35s	remaining: 2.22s
# 601:	learn: 0.0785116	total: 3.36s	remaining: 2.22s
# 602:	learn: 0.0783977	total: 3.36s	remaining: 2.21s
# 603:	learn: 0.0783517	total: 3.37s	remaining: 2.21s
# 604:	learn: 0.0783075	total: 3.37s	remaining: 2.2s
# 605:	learn: 0.0782280	total: 3.38s	remaining: 2.2s
# 606:	learn: 0.0781671	total: 3.38s	remaining: 2.19s
# 607:	learn: 0.0781273	total: 3.39s	remaining: 2.19s
# 608:	learn: 0.0780923	total: 3.4s	remaining: 2.18s
# 609:	learn: 0.0780693	total: 3.4s	remaining: 2.17s
# 610:	learn: 0.0780578	total: 3.41s	remaining: 2.17s
# 611:	learn: 0.0779725	total: 3.41s	remaining: 2.16s
# 612:	learn: 0.0778834	total: 3.42s	remaining: 2.16s
# 613:	learn: 0.0778530	total: 3.42s	remaining: 2.15s
# 614:	learn: 0.0778008	total: 3.43s	remaining: 2.15s
# 615:	learn: 0.0777299	total: 3.43s	remaining: 2.14s
# 616:	learn: 0.0776456	total: 3.44s	remaining: 2.13s
# 617:	learn: 0.0775846	total: 3.44s	remaining: 2.13s
# 618:	learn: 0.0775127	total: 3.45s	remaining: 2.12s
# 619:	learn: 0.0774870	total: 3.45s	remaining: 2.12s
# 620:	learn: 0.0774341	total: 3.46s	remaining: 2.11s
# 621:	learn: 0.0773672	total: 3.46s	remaining: 2.11s
# 622:	learn: 0.0772867	total: 3.47s	remaining: 2.1s
# 623:	learn: 0.0771200	total: 3.48s	remaining: 2.09s
# 624:	learn: 0.0770732	total: 3.48s	remaining: 2.09s
# 625:	learn: 0.0770403	total: 3.49s	remaining: 2.08s
# 626:	learn: 0.0770083	total: 3.49s	remaining: 2.08s
# 627:	learn: 0.0769385	total: 3.5s	remaining: 2.07s
# 628:	learn: 0.0769042	total: 3.5s	remaining: 2.06s
# 629:	learn: 0.0768497	total: 3.51s	remaining: 2.06s
# 630:	learn: 0.0768336	total: 3.51s	remaining: 2.05s
# 631:	learn: 0.0767399	total: 3.52s	remaining: 2.05s
# 632:	learn: 0.0767107	total: 3.52s	remaining: 2.04s
# 633:	learn: 0.0766720	total: 3.53s	remaining: 2.04s
# 634:	learn: 0.0766168	total: 3.53s	remaining: 2.03s
# 635:	learn: 0.0765271	total: 3.54s	remaining: 2.02s
# 636:	learn: 0.0764759	total: 3.54s	remaining: 2.02s
# 637:	learn: 0.0764598	total: 3.55s	remaining: 2.01s
# 638:	learn: 0.0764128	total: 3.55s	remaining: 2.01s
# 639:	learn: 0.0763684	total: 3.56s	remaining: 2s
# 640:	learn: 0.0763108	total: 3.56s	remaining: 2s
# 641:	learn: 0.0762683	total: 3.57s	remaining: 1.99s
# 642:	learn: 0.0761729	total: 3.57s	remaining: 1.98s
# 643:	learn: 0.0761006	total: 3.58s	remaining: 1.98s
# 644:	learn: 0.0760210	total: 3.58s	remaining: 1.97s
# 645:	learn: 0.0759439	total: 3.59s	remaining: 1.97s
# 646:	learn: 0.0759195	total: 3.59s	remaining: 1.96s
# 647:	learn: 0.0758522	total: 3.6s	remaining: 1.96s
# 648:	learn: 0.0758151	total: 3.6s	remaining: 1.95s
# 649:	learn: 0.0757673	total: 3.61s	remaining: 1.94s
# 650:	learn: 0.0756940	total: 3.62s	remaining: 1.94s
# 651:	learn: 0.0756527	total: 3.62s	remaining: 1.93s
# 652:	learn: 0.0755644	total: 3.63s	remaining: 1.93s
# 653:	learn: 0.0755308	total: 3.63s	remaining: 1.92s
# 654:	learn: 0.0754901	total: 3.64s	remaining: 1.92s
# 655:	learn: 0.0754528	total: 3.64s	remaining: 1.91s
# 656:	learn: 0.0753934	total: 3.65s	remaining: 1.9s
# 657:	learn: 0.0753769	total: 3.65s	remaining: 1.9s
# 658:	learn: 0.0753549	total: 3.66s	remaining: 1.89s
# 659:	learn: 0.0753058	total: 3.66s	remaining: 1.89s
# 660:	learn: 0.0752698	total: 3.67s	remaining: 1.88s
# 661:	learn: 0.0752191	total: 3.67s	remaining: 1.88s
# 662:	learn: 0.0751916	total: 3.68s	remaining: 1.87s
# 663:	learn: 0.0751581	total: 3.68s	remaining: 1.86s
# 664:	learn: 0.0751426	total: 3.69s	remaining: 1.86s
# 665:	learn: 0.0750335	total: 3.69s	remaining: 1.85s
# 666:	learn: 0.0749934	total: 3.7s	remaining: 1.85s
# 667:	learn: 0.0749659	total: 3.7s	remaining: 1.84s
# 668:	learn: 0.0749291	total: 3.71s	remaining: 1.83s
# 669:	learn: 0.0748778	total: 3.71s	remaining: 1.83s
# 670:	learn: 0.0748308	total: 3.72s	remaining: 1.82s
# 671:	learn: 0.0747876	total: 3.72s	remaining: 1.82s
# 672:	learn: 0.0747582	total: 3.73s	remaining: 1.81s
# 673:	learn: 0.0747325	total: 3.73s	remaining: 1.81s
# 674:	learn: 0.0746864	total: 3.74s	remaining: 1.8s
# 675:	learn: 0.0746293	total: 3.75s	remaining: 1.79s
# 676:	learn: 0.0745960	total: 3.75s	remaining: 1.79s
# 677:	learn: 0.0745306	total: 3.76s	remaining: 1.78s
# 678:	learn: 0.0744445	total: 3.76s	remaining: 1.78s
# 679:	learn: 0.0743971	total: 3.77s	remaining: 1.77s
# 680:	learn: 0.0743780	total: 3.77s	remaining: 1.77s
# 681:	learn: 0.0743194	total: 3.78s	remaining: 1.76s
# 682:	learn: 0.0742603	total: 3.78s	remaining: 1.75s
# 683:	learn: 0.0742251	total: 3.79s	remaining: 1.75s
# 684:	learn: 0.0741167	total: 3.79s	remaining: 1.74s
# 685:	learn: 0.0740471	total: 3.8s	remaining: 1.74s
# 686:	learn: 0.0739953	total: 3.8s	remaining: 1.73s
# 687:	learn: 0.0739403	total: 3.81s	remaining: 1.73s
# 688:	learn: 0.0739021	total: 3.81s	remaining: 1.72s
# 689:	learn: 0.0738532	total: 3.82s	remaining: 1.72s
# 690:	learn: 0.0738027	total: 3.83s	remaining: 1.71s
# 691:	learn: 0.0737134	total: 3.83s	remaining: 1.7s
# 692:	learn: 0.0736607	total: 3.83s	remaining: 1.7s
# 693:	learn: 0.0736393	total: 3.84s	remaining: 1.69s
# 694:	learn: 0.0735662	total: 3.85s	remaining: 1.69s
# 695:	learn: 0.0735102	total: 3.85s	remaining: 1.68s
# 696:	learn: 0.0734775	total: 3.86s	remaining: 1.68s
# 697:	learn: 0.0734320	total: 3.86s	remaining: 1.67s
# 698:	learn: 0.0733416	total: 3.87s	remaining: 1.66s
# 699:	learn: 0.0732971	total: 3.87s	remaining: 1.66s
# 700:	learn: 0.0731881	total: 3.88s	remaining: 1.65s
# 701:	learn: 0.0731505	total: 3.88s	remaining: 1.65s
# 702:	learn: 0.0731021	total: 3.89s	remaining: 1.64s
# 703:	learn: 0.0730497	total: 3.89s	remaining: 1.64s
# 704:	learn: 0.0730450	total: 3.9s	remaining: 1.63s
# 705:	learn: 0.0730076	total: 3.9s	remaining: 1.63s
# 706:	learn: 0.0729066	total: 3.91s	remaining: 1.62s
# 707:	learn: 0.0728754	total: 3.91s	remaining: 1.61s
# 708:	learn: 0.0728086	total: 3.92s	remaining: 1.61s
# 709:	learn: 0.0727374	total: 3.92s	remaining: 1.6s
# 710:	learn: 0.0726825	total: 3.93s	remaining: 1.6s
# 711:	learn: 0.0726555	total: 3.94s	remaining: 1.59s
# 712:	learn: 0.0725916	total: 3.94s	remaining: 1.59s
# 713:	learn: 0.0725403	total: 3.94s	remaining: 1.58s
# 714:	learn: 0.0724599	total: 3.95s	remaining: 1.57s
# 715:	learn: 0.0723612	total: 3.96s	remaining: 1.57s
# 716:	learn: 0.0722979	total: 3.96s	remaining: 1.56s
# 717:	learn: 0.0722424	total: 3.97s	remaining: 1.56s
# 718:	learn: 0.0721945	total: 3.97s	remaining: 1.55s
# 719:	learn: 0.0721588	total: 3.98s	remaining: 1.55s
# 720:	learn: 0.0721184	total: 3.98s	remaining: 1.54s
# 721:	learn: 0.0720646	total: 3.99s	remaining: 1.53s
# 722:	learn: 0.0720311	total: 3.99s	remaining: 1.53s
# 723:	learn: 0.0719459	total: 4s	remaining: 1.52s
# 724:	learn: 0.0719072	total: 4s	remaining: 1.52s
# 725:	learn: 0.0718595	total: 4.01s	remaining: 1.51s
# 726:	learn: 0.0718151	total: 4.01s	remaining: 1.51s
# 727:	learn: 0.0718065	total: 4.02s	remaining: 1.5s
# 728:	learn: 0.0717562	total: 4.03s	remaining: 1.5s
# 729:	learn: 0.0717297	total: 4.03s	remaining: 1.49s
# 730:	learn: 0.0716798	total: 4.04s	remaining: 1.49s
# 731:	learn: 0.0716294	total: 4.04s	remaining: 1.48s
# 732:	learn: 0.0715942	total: 4.05s	remaining: 1.47s
# 733:	learn: 0.0715465	total: 4.05s	remaining: 1.47s
# 734:	learn: 0.0715108	total: 4.06s	remaining: 1.46s
# 735:	learn: 0.0714839	total: 4.06s	remaining: 1.46s
# 736:	learn: 0.0714563	total: 4.07s	remaining: 1.45s
# 737:	learn: 0.0713946	total: 4.07s	remaining: 1.45s
# 738:	learn: 0.0713550	total: 4.08s	remaining: 1.44s
# 739:	learn: 0.0712960	total: 4.08s	remaining: 1.43s
# 740:	learn: 0.0712679	total: 4.09s	remaining: 1.43s
# 741:	learn: 0.0712453	total: 4.09s	remaining: 1.42s
# 742:	learn: 0.0711875	total: 4.1s	remaining: 1.42s
# 743:	learn: 0.0711323	total: 4.1s	remaining: 1.41s
# 744:	learn: 0.0711024	total: 4.11s	remaining: 1.41s
# 745:	learn: 0.0710591	total: 4.12s	remaining: 1.4s
# 746:	learn: 0.0710266	total: 4.12s	remaining: 1.4s
# 747:	learn: 0.0709984	total: 4.13s	remaining: 1.39s
# 748:	learn: 0.0709161	total: 4.13s	remaining: 1.38s
# 749:	learn: 0.0708809	total: 4.14s	remaining: 1.38s
# 750:	learn: 0.0708497	total: 4.14s	remaining: 1.37s
# 751:	learn: 0.0708207	total: 4.15s	remaining: 1.37s
# 752:	learn: 0.0708167	total: 4.15s	remaining: 1.36s
# 753:	learn: 0.0707872	total: 4.16s	remaining: 1.36s
# 754:	learn: 0.0707383	total: 4.16s	remaining: 1.35s
# 755:	learn: 0.0707067	total: 4.17s	remaining: 1.34s
# 756:	learn: 0.0706797	total: 4.17s	remaining: 1.34s
# 757:	learn: 0.0706130	total: 4.18s	remaining: 1.33s
# 758:	learn: 0.0705329	total: 4.18s	remaining: 1.33s
# 759:	learn: 0.0704935	total: 4.19s	remaining: 1.32s
# 760:	learn: 0.0704025	total: 4.2s	remaining: 1.32s
# 761:	learn: 0.0703682	total: 4.2s	remaining: 1.31s
# 762:	learn: 0.0703277	total: 4.21s	remaining: 1.31s
# 763:	learn: 0.0702916	total: 4.21s	remaining: 1.3s
# 764:	learn: 0.0702563	total: 4.22s	remaining: 1.29s
# 765:	learn: 0.0702067	total: 4.22s	remaining: 1.29s
# 766:	learn: 0.0701984	total: 4.23s	remaining: 1.28s
# 767:	learn: 0.0701074	total: 4.23s	remaining: 1.28s
# 768:	learn: 0.0700814	total: 4.24s	remaining: 1.27s
# 769:	learn: 0.0700780	total: 4.24s	remaining: 1.27s
# 770:	learn: 0.0700353	total: 4.25s	remaining: 1.26s
# 771:	learn: 0.0699952	total: 4.25s	remaining: 1.26s
# 772:	learn: 0.0699351	total: 4.26s	remaining: 1.25s
# 773:	learn: 0.0699070	total: 4.26s	remaining: 1.24s
# 774:	learn: 0.0698841	total: 4.27s	remaining: 1.24s
# 775:	learn: 0.0698458	total: 4.27s	remaining: 1.23s
# 776:	learn: 0.0698040	total: 4.28s	remaining: 1.23s
# 777:	learn: 0.0697425	total: 4.28s	remaining: 1.22s
# 778:	learn: 0.0697391	total: 4.29s	remaining: 1.22s
# 779:	learn: 0.0697089	total: 4.29s	remaining: 1.21s
# 780:	learn: 0.0696584	total: 4.3s	remaining: 1.21s
# 781:	learn: 0.0696042	total: 4.3s	remaining: 1.2s
# 782:	learn: 0.0695520	total: 4.31s	remaining: 1.19s
# 783:	learn: 0.0694928	total: 4.32s	remaining: 1.19s
# 784:	learn: 0.0694236	total: 4.32s	remaining: 1.18s
# 785:	learn: 0.0693558	total: 4.33s	remaining: 1.18s
# 786:	learn: 0.0693088	total: 4.33s	remaining: 1.17s
# 787:	learn: 0.0692508	total: 4.33s	remaining: 1.17s
# 788:	learn: 0.0692016	total: 4.34s	remaining: 1.16s
# 789:	learn: 0.0691605	total: 4.35s	remaining: 1.16s
# 790:	learn: 0.0691070	total: 4.35s	remaining: 1.15s
# 791:	learn: 0.0690951	total: 4.36s	remaining: 1.14s
# 792:	learn: 0.0690510	total: 4.36s	remaining: 1.14s
# 793:	learn: 0.0690478	total: 4.37s	remaining: 1.13s
# 794:	learn: 0.0689971	total: 4.37s	remaining: 1.13s
# 795:	learn: 0.0689732	total: 4.38s	remaining: 1.12s
# 796:	learn: 0.0688964	total: 4.38s	remaining: 1.12s
# 797:	learn: 0.0688378	total: 4.39s	remaining: 1.11s
# 798:	learn: 0.0687868	total: 4.39s	remaining: 1.1s
# 799:	learn: 0.0687520	total: 4.4s	remaining: 1.1s
# 800:	learn: 0.0687028	total: 4.4s	remaining: 1.09s
# 801:	learn: 0.0686694	total: 4.41s	remaining: 1.09s
# 802:	learn: 0.0685972	total: 4.41s	remaining: 1.08s
# 803:	learn: 0.0685737	total: 4.42s	remaining: 1.08s
# 804:	learn: 0.0685232	total: 4.42s	remaining: 1.07s
# 805:	learn: 0.0684879	total: 4.43s	remaining: 1.06s
# 806:	learn: 0.0684477	total: 4.43s	remaining: 1.06s
# 807:	learn: 0.0684016	total: 4.44s	remaining: 1.05s
# 808:	learn: 0.0683679	total: 4.45s	remaining: 1.05s
# 809:	learn: 0.0683000	total: 4.45s	remaining: 1.04s
# 810:	learn: 0.0682777	total: 4.46s	remaining: 1.04s
# 811:	learn: 0.0682359	total: 4.46s	remaining: 1.03s
# 812:	learn: 0.0682108	total: 4.47s	remaining: 1.03s
# 813:	learn: 0.0681738	total: 4.47s	remaining: 1.02s
# 814:	learn: 0.0681438	total: 4.48s	remaining: 1.02s
# 815:	learn: 0.0681021	total: 4.48s	remaining: 1.01s
# 816:	learn: 0.0680661	total: 4.49s	remaining: 1s
# 817:	learn: 0.0680553	total: 4.49s	remaining: 1000ms
# 818:	learn: 0.0680518	total: 4.5s	remaining: 994ms
# 819:	learn: 0.0680176	total: 4.5s	remaining: 989ms
# 820:	learn: 0.0679839	total: 4.51s	remaining: 983ms
# 821:	learn: 0.0678957	total: 4.51s	remaining: 978ms
# 822:	learn: 0.0678597	total: 4.52s	remaining: 972ms
# 823:	learn: 0.0678211	total: 4.52s	remaining: 966ms
# 824:	learn: 0.0677686	total: 4.53s	remaining: 961ms
# 825:	learn: 0.0677080	total: 4.53s	remaining: 955ms
# 826:	learn: 0.0676724	total: 4.54s	remaining: 950ms
# 827:	learn: 0.0676439	total: 4.54s	remaining: 944ms
# 828:	learn: 0.0676407	total: 4.55s	remaining: 939ms
# 829:	learn: 0.0676135	total: 4.56s	remaining: 933ms
# 830:	learn: 0.0675923	total: 4.56s	remaining: 928ms
# 831:	learn: 0.0675579	total: 4.57s	remaining: 922ms
# 832:	learn: 0.0675315	total: 4.57s	remaining: 917ms
# 833:	learn: 0.0675081	total: 4.58s	remaining: 911ms
# 834:	learn: 0.0674835	total: 4.58s	remaining: 906ms
# 835:	learn: 0.0673944	total: 4.59s	remaining: 900ms
# 836:	learn: 0.0673523	total: 4.59s	remaining: 895ms
# 837:	learn: 0.0673062	total: 4.6s	remaining: 889ms
# 838:	learn: 0.0672573	total: 4.61s	remaining: 884ms
# 839:	learn: 0.0672269	total: 4.61s	remaining: 878ms
# 840:	learn: 0.0671478	total: 4.62s	remaining: 873ms
# 841:	learn: 0.0671048	total: 4.62s	remaining: 867ms
# 842:	learn: 0.0670515	total: 4.63s	remaining: 862ms
# 843:	learn: 0.0670242	total: 4.63s	remaining: 856ms
# 844:	learn: 0.0669945	total: 4.64s	remaining: 851ms
# 845:	learn: 0.0669503	total: 4.64s	remaining: 845ms
# 846:	learn: 0.0669017	total: 4.65s	remaining: 839ms
# 847:	learn: 0.0668270	total: 4.65s	remaining: 834ms
# 848:	learn: 0.0667586	total: 4.66s	remaining: 828ms
# 849:	learn: 0.0667252	total: 4.66s	remaining: 823ms
# 850:	learn: 0.0667036	total: 4.67s	remaining: 817ms
# 851:	learn: 0.0666681	total: 4.67s	remaining: 812ms
# 852:	learn: 0.0666176	total: 4.68s	remaining: 806ms
# 853:	learn: 0.0665591	total: 4.68s	remaining: 801ms
# 854:	learn: 0.0665217	total: 4.69s	remaining: 795ms
# 855:	learn: 0.0664889	total: 4.69s	remaining: 790ms
# 856:	learn: 0.0663641	total: 4.7s	remaining: 784ms
# 857:	learn: 0.0663569	total: 4.7s	remaining: 779ms
# 858:	learn: 0.0663203	total: 4.71s	remaining: 773ms
# 859:	learn: 0.0662786	total: 4.71s	remaining: 767ms
# 860:	learn: 0.0662554	total: 4.72s	remaining: 762ms
# 861:	learn: 0.0662070	total: 4.72s	remaining: 756ms
# 862:	learn: 0.0661611	total: 4.73s	remaining: 751ms
# 863:	learn: 0.0661223	total: 4.74s	remaining: 745ms
# 864:	learn: 0.0660685	total: 4.74s	remaining: 740ms
# 865:	learn: 0.0659874	total: 4.75s	remaining: 734ms
# 866:	learn: 0.0659396	total: 4.75s	remaining: 729ms
# 867:	learn: 0.0659156	total: 4.76s	remaining: 723ms
# 868:	learn: 0.0658805	total: 4.76s	remaining: 718ms
# 869:	learn: 0.0658244	total: 4.77s	remaining: 712ms
# 870:	learn: 0.0657838	total: 4.77s	remaining: 707ms
# 871:	learn: 0.0657431	total: 4.78s	remaining: 701ms
# 872:	learn: 0.0657005	total: 4.78s	remaining: 696ms
# 873:	learn: 0.0656741	total: 4.79s	remaining: 690ms
# 874:	learn: 0.0656550	total: 4.79s	remaining: 685ms
# 875:	learn: 0.0656402	total: 4.8s	remaining: 679ms
# 876:	learn: 0.0656060	total: 4.8s	remaining: 674ms
# 877:	learn: 0.0655969	total: 4.81s	remaining: 668ms
# 878:	learn: 0.0655768	total: 4.81s	remaining: 663ms
# 879:	learn: 0.0655317	total: 4.82s	remaining: 657ms
# 880:	learn: 0.0654942	total: 4.82s	remaining: 652ms
# 881:	learn: 0.0654629	total: 4.83s	remaining: 646ms
# 882:	learn: 0.0654241	total: 4.83s	remaining: 641ms
# 883:	learn: 0.0653755	total: 4.84s	remaining: 635ms
# 884:	learn: 0.0653484	total: 4.84s	remaining: 629ms
# 885:	learn: 0.0653254	total: 4.85s	remaining: 624ms
# 886:	learn: 0.0652650	total: 4.85s	remaining: 618ms
# 887:	learn: 0.0652216	total: 4.86s	remaining: 613ms
# 888:	learn: 0.0651845	total: 4.87s	remaining: 608ms
# 889:	learn: 0.0651488	total: 4.87s	remaining: 602ms
# 890:	learn: 0.0651180	total: 4.88s	remaining: 597ms
# 891:	learn: 0.0650592	total: 4.88s	remaining: 591ms
# 892:	learn: 0.0650161	total: 4.89s	remaining: 586ms
# 893:	learn: 0.0650142	total: 4.89s	remaining: 580ms
# 894:	learn: 0.0649628	total: 4.9s	remaining: 575ms
# 895:	learn: 0.0649522	total: 4.9s	remaining: 569ms
# 896:	learn: 0.0649038	total: 4.91s	remaining: 564ms
# 897:	learn: 0.0648655	total: 4.91s	remaining: 558ms
# 898:	learn: 0.0648358	total: 4.92s	remaining: 553ms
# 899:	learn: 0.0647906	total: 4.92s	remaining: 547ms
# 900:	learn: 0.0647676	total: 4.93s	remaining: 542ms
# 901:	learn: 0.0647041	total: 4.93s	remaining: 536ms
# 902:	learn: 0.0646677	total: 4.94s	remaining: 531ms
# 903:	learn: 0.0646262	total: 4.95s	remaining: 525ms
# 904:	learn: 0.0646045	total: 4.95s	remaining: 520ms
# 905:	learn: 0.0645701	total: 4.96s	remaining: 514ms
# 906:	learn: 0.0645385	total: 4.96s	remaining: 509ms
# 907:	learn: 0.0645097	total: 4.97s	remaining: 503ms
# 908:	learn: 0.0644752	total: 4.97s	remaining: 498ms
# 909:	learn: 0.0644414	total: 4.98s	remaining: 493ms
# 910:	learn: 0.0644181	total: 4.99s	remaining: 487ms
# 911:	learn: 0.0643601	total: 4.99s	remaining: 482ms
# 912:	learn: 0.0643400	total: 5s	remaining: 476ms
# 913:	learn: 0.0642622	total: 5s	remaining: 471ms
# 914:	learn: 0.0642253	total: 5s	remaining: 465ms
# 915:	learn: 0.0642086	total: 5.01s	remaining: 459ms
# 916:	learn: 0.0641410	total: 5.01s	remaining: 454ms
# 917:	learn: 0.0641182	total: 5.02s	remaining: 448ms
# 918:	learn: 0.0640820	total: 5.03s	remaining: 443ms
# ...
# 692:	learn: 0.0524587	total: 5.66s	remaining: 2.51s
# 693:	learn: 0.0523815	total: 5.67s	remaining: 2.5s
# 694:	learn: 0.0523419	total: 5.68s	remaining: 2.49s
# 695:	learn: 0.0522728	total: 5.69s	remaining: 2.48s
# 696:	learn: 0.0522202	total: 5.7s	remaining: 2.48s
# 697:	learn: 0.0521747	total: 5.7s	remaining: 2.47s
# 698:	learn: 0.0521308	total: 5.71s	remaining: 2.46s
# 699:	learn: 0.0520542	total: 5.72s	remaining: 2.45s
# 700:	learn: 0.0520072	total: 5.73s	remaining: 2.44s
# 701:	learn: 0.0519305	total: 5.74s	remaining: 2.43s
# 702:	learn: 0.0518580	total: 5.74s	remaining: 2.43s
# 703:	learn: 0.0518213	total: 5.75s	remaining: 2.42s
# 704:	learn: 0.0517592	total: 5.76s	remaining: 2.41s
# 705:	learn: 0.0517111	total: 5.77s	remaining: 2.4s
# 706:	learn: 0.0516221	total: 5.77s	remaining: 2.39s
# 707:	learn: 0.0515957	total: 5.78s	remaining: 2.38s
# 708:	learn: 0.0515549	total: 5.79s	remaining: 2.38s
# 709:	learn: 0.0515195	total: 5.8s	remaining: 2.37s
# 710:	learn: 0.0514698	total: 5.8s	remaining: 2.36s
# 711:	learn: 0.0514166	total: 5.81s	remaining: 2.35s
# 712:	learn: 0.0513835	total: 5.82s	remaining: 2.34s
# 713:	learn: 0.0513237	total: 5.83s	remaining: 2.33s
# 714:	learn: 0.0512967	total: 5.84s	remaining: 2.33s
# 715:	learn: 0.0512480	total: 5.85s	remaining: 2.32s
# 716:	learn: 0.0511724	total: 5.86s	remaining: 2.31s
# 717:	learn: 0.0511225	total: 5.87s	remaining: 2.3s
# 718:	learn: 0.0510708	total: 5.87s	remaining: 2.29s
# 719:	learn: 0.0510254	total: 5.88s	remaining: 2.29s
# 720:	learn: 0.0509936	total: 5.89s	remaining: 2.28s
# 721:	learn: 0.0509537	total: 5.9s	remaining: 2.27s
# 722:	learn: 0.0508745	total: 5.91s	remaining: 2.26s
# 723:	learn: 0.0508177	total: 5.91s	remaining: 2.25s
# 724:	learn: 0.0507880	total: 5.92s	remaining: 2.25s
# 725:	learn: 0.0507481	total: 5.93s	remaining: 2.24s
# 726:	learn: 0.0507069	total: 5.94s	remaining: 2.23s
# 727:	learn: 0.0506539	total: 5.94s	remaining: 2.22s
# 728:	learn: 0.0506105	total: 5.95s	remaining: 2.21s
# 729:	learn: 0.0505472	total: 5.96s	remaining: 2.2s
# 730:	learn: 0.0504727	total: 5.97s	remaining: 2.2s
# 731:	learn: 0.0504429	total: 5.98s	remaining: 2.19s
# 732:	learn: 0.0504070	total: 5.98s	remaining: 2.18s
# 733:	learn: 0.0503749	total: 5.99s	remaining: 2.17s
# 734:	learn: 0.0503351	total: 6s	remaining: 2.16s
# 735:	learn: 0.0502876	total: 6.01s	remaining: 2.15s
# 736:	learn: 0.0502152	total: 6.02s	remaining: 2.15s
# 737:	learn: 0.0501621	total: 6.03s	remaining: 2.14s
# 738:	learn: 0.0500970	total: 6.03s	remaining: 2.13s
# 739:	learn: 0.0500532	total: 6.04s	remaining: 2.12s
# 740:	learn: 0.0499954	total: 6.05s	remaining: 2.11s
# 741:	learn: 0.0499440	total: 6.06s	remaining: 2.11s
# 742:	learn: 0.0499060	total: 6.06s	remaining: 2.1s
# 743:	learn: 0.0498806	total: 6.07s	remaining: 2.09s
# 744:	learn: 0.0498087	total: 6.08s	remaining: 2.08s
# 745:	learn: 0.0497898	total: 6.09s	remaining: 2.07s
# 746:	learn: 0.0497504	total: 6.09s	remaining: 2.06s
# 747:	learn: 0.0497070	total: 6.1s	remaining: 2.06s
# 748:	learn: 0.0496414	total: 6.11s	remaining: 2.05s
# 749:	learn: 0.0495334	total: 6.12s	remaining: 2.04s
# 750:	learn: 0.0495011	total: 6.13s	remaining: 2.03s
# 751:	learn: 0.0494677	total: 6.13s	remaining: 2.02s
# 752:	learn: 0.0494312	total: 6.14s	remaining: 2.02s
# 753:	learn: 0.0493977	total: 6.15s	remaining: 2.01s
# 754:	learn: 0.0493522	total: 6.16s	remaining: 2s
# 755:	learn: 0.0493051	total: 6.17s	remaining: 1.99s
# 756:	learn: 0.0492627	total: 6.17s	remaining: 1.98s
# 757:	learn: 0.0492387	total: 6.18s	remaining: 1.97s
# 758:	learn: 0.0491972	total: 6.19s	remaining: 1.97s
# 759:	learn: 0.0491541	total: 6.2s	remaining: 1.96s
# 760:	learn: 0.0491277	total: 6.2s	remaining: 1.95s
# 761:	learn: 0.0490886	total: 6.21s	remaining: 1.94s
# 762:	learn: 0.0490397	total: 6.22s	remaining: 1.93s
# 763:	learn: 0.0490139	total: 6.23s	remaining: 1.92s
# 764:	learn: 0.0489948	total: 6.24s	remaining: 1.92s
# 765:	learn: 0.0489299	total: 6.25s	remaining: 1.91s
# 766:	learn: 0.0488686	total: 6.25s	remaining: 1.9s
# 767:	learn: 0.0488351	total: 6.26s	remaining: 1.89s
# 768:	learn: 0.0487760	total: 6.27s	remaining: 1.88s
# 769:	learn: 0.0487279	total: 6.28s	remaining: 1.88s
# 770:	learn: 0.0487072	total: 6.29s	remaining: 1.87s
# 771:	learn: 0.0486433	total: 6.29s	remaining: 1.86s
# 772:	learn: 0.0485481	total: 6.3s	remaining: 1.85s
# 773:	learn: 0.0485262	total: 6.31s	remaining: 1.84s
# 774:	learn: 0.0484729	total: 6.32s	remaining: 1.83s
# 775:	learn: 0.0484352	total: 6.32s	remaining: 1.82s
# 776:	learn: 0.0484075	total: 6.33s	remaining: 1.82s
# 777:	learn: 0.0483641	total: 6.34s	remaining: 1.81s
# 778:	learn: 0.0483315	total: 6.35s	remaining: 1.8s
# 779:	learn: 0.0483099	total: 6.36s	remaining: 1.79s
# 780:	learn: 0.0482672	total: 6.36s	remaining: 1.78s
# 781:	learn: 0.0482229	total: 6.37s	remaining: 1.78s
# 782:	learn: 0.0481982	total: 6.38s	remaining: 1.77s
# 783:	learn: 0.0481718	total: 6.39s	remaining: 1.76s
# 784:	learn: 0.0481273	total: 6.4s	remaining: 1.75s
# 785:	learn: 0.0481054	total: 6.4s	remaining: 1.74s
# 786:	learn: 0.0480542	total: 6.41s	remaining: 1.74s
# 787:	learn: 0.0480180	total: 6.42s	remaining: 1.73s
# 788:	learn: 0.0479859	total: 6.43s	remaining: 1.72s
# 789:	learn: 0.0479225	total: 6.43s	remaining: 1.71s
# 790:	learn: 0.0478941	total: 6.44s	remaining: 1.7s
# 791:	learn: 0.0478657	total: 6.45s	remaining: 1.69s
# 792:	learn: 0.0478081	total: 6.46s	remaining: 1.69s
# 793:	learn: 0.0477444	total: 6.47s	remaining: 1.68s
# 794:	learn: 0.0477087	total: 6.48s	remaining: 1.67s
# 795:	learn: 0.0476702	total: 6.48s	remaining: 1.66s
# 796:	learn: 0.0475973	total: 6.49s	remaining: 1.65s
# 797:	learn: 0.0475599	total: 6.5s	remaining: 1.65s
# 798:	learn: 0.0474995	total: 6.51s	remaining: 1.64s
# 799:	learn: 0.0474656	total: 6.52s	remaining: 1.63s
# 800:	learn: 0.0474234	total: 6.53s	remaining: 1.62s
# 801:	learn: 0.0473957	total: 6.54s	remaining: 1.61s
# 802:	learn: 0.0473642	total: 6.55s	remaining: 1.61s
# 803:	learn: 0.0472859	total: 6.55s	remaining: 1.6s
# 804:	learn: 0.0472504	total: 6.56s	remaining: 1.59s
# 805:	learn: 0.0472223	total: 6.57s	remaining: 1.58s
# 806:	learn: 0.0471903	total: 6.58s	remaining: 1.57s
# 807:	learn: 0.0471641	total: 6.59s	remaining: 1.56s
# 808:	learn: 0.0471259	total: 6.59s	remaining: 1.56s
# 809:	learn: 0.0470826	total: 6.6s	remaining: 1.55s
# 810:	learn: 0.0470588	total: 6.61s	remaining: 1.54s
# 811:	learn: 0.0470152	total: 6.62s	remaining: 1.53s
# 812:	learn: 0.0469767	total: 6.64s	remaining: 1.53s
# 813:	learn: 0.0469251	total: 6.65s	remaining: 1.52s
# 814:	learn: 0.0468846	total: 6.66s	remaining: 1.51s
# 815:	learn: 0.0468330	total: 6.66s	remaining: 1.5s
# 816:	learn: 0.0467753	total: 6.67s	remaining: 1.49s
# 817:	learn: 0.0467509	total: 6.68s	remaining: 1.49s
# 818:	learn: 0.0467187	total: 6.69s	remaining: 1.48s
# 819:	learn: 0.0466830	total: 6.7s	remaining: 1.47s
# 820:	learn: 0.0466373	total: 6.7s	remaining: 1.46s
# 821:	learn: 0.0465988	total: 6.71s	remaining: 1.45s
# 822:	learn: 0.0465297	total: 6.72s	remaining: 1.45s
# 823:	learn: 0.0464999	total: 6.73s	remaining: 1.44s
# 824:	learn: 0.0464496	total: 6.74s	remaining: 1.43s
# 825:	learn: 0.0464162	total: 6.74s	remaining: 1.42s
# 826:	learn: 0.0463905	total: 6.75s	remaining: 1.41s
# 827:	learn: 0.0463228	total: 6.76s	remaining: 1.4s
# 828:	learn: 0.0462862	total: 6.77s	remaining: 1.4s
# 829:	learn: 0.0462477	total: 6.78s	remaining: 1.39s
# 830:	learn: 0.0461783	total: 6.78s	remaining: 1.38s
# 831:	learn: 0.0461398	total: 6.79s	remaining: 1.37s
# 832:	learn: 0.0460706	total: 6.8s	remaining: 1.36s
# 833:	learn: 0.0460365	total: 6.81s	remaining: 1.35s
# 834:	learn: 0.0459754	total: 6.82s	remaining: 1.35s
# 835:	learn: 0.0459311	total: 6.82s	remaining: 1.34s
# 836:	learn: 0.0458921	total: 6.83s	remaining: 1.33s
# 837:	learn: 0.0458468	total: 6.84s	remaining: 1.32s
# 838:	learn: 0.0458224	total: 6.85s	remaining: 1.31s
# 839:	learn: 0.0457594	total: 6.85s	remaining: 1.3s
# 840:	learn: 0.0457304	total: 6.86s	remaining: 1.3s
# 841:	learn: 0.0456957	total: 6.87s	remaining: 1.29s
# 842:	learn: 0.0456551	total: 6.88s	remaining: 1.28s
# 843:	learn: 0.0455939	total: 6.89s	remaining: 1.27s
# 844:	learn: 0.0455580	total: 6.89s	remaining: 1.26s
# 845:	learn: 0.0455133	total: 6.9s	remaining: 1.26s
# 846:	learn: 0.0454980	total: 6.91s	remaining: 1.25s
# 847:	learn: 0.0454651	total: 6.92s	remaining: 1.24s
# 848:	learn: 0.0454133	total: 6.92s	remaining: 1.23s
# 849:	learn: 0.0453680	total: 6.93s	remaining: 1.22s
# 850:	learn: 0.0453418	total: 6.94s	remaining: 1.22s
# 851:	learn: 0.0452831	total: 6.95s	remaining: 1.21s
# 852:	learn: 0.0452463	total: 6.96s	remaining: 1.2s
# 853:	learn: 0.0451912	total: 6.96s	remaining: 1.19s
# 854:	learn: 0.0451471	total: 6.97s	remaining: 1.18s
# 855:	learn: 0.0451057	total: 6.98s	remaining: 1.17s
# 856:	learn: 0.0450570	total: 6.99s	remaining: 1.17s
# 857:	learn: 0.0450320	total: 6.99s	remaining: 1.16s
# 858:	learn: 0.0450114	total: 7s	remaining: 1.15s
# 859:	learn: 0.0449620	total: 7.01s	remaining: 1.14s
# 860:	learn: 0.0449193	total: 7.02s	remaining: 1.13s
# 861:	learn: 0.0448782	total: 7.03s	remaining: 1.12s
# 862:	learn: 0.0448462	total: 7.03s	remaining: 1.12s
# 863:	learn: 0.0448089	total: 7.04s	remaining: 1.11s
# 864:	learn: 0.0447726	total: 7.05s	remaining: 1.1s
# 865:	learn: 0.0447352	total: 7.06s	remaining: 1.09s
# 866:	learn: 0.0447103	total: 7.07s	remaining: 1.08s
# 867:	learn: 0.0446809	total: 7.08s	remaining: 1.08s
# 868:	learn: 0.0446447	total: 7.08s	remaining: 1.07s
# 869:	learn: 0.0446295	total: 7.09s	remaining: 1.06s
# 870:	learn: 0.0446154	total: 7.1s	remaining: 1.05s
# 871:	learn: 0.0445440	total: 7.11s	remaining: 1.04s
# 872:	learn: 0.0445174	total: 7.12s	remaining: 1.03s
# 873:	learn: 0.0444912	total: 7.12s	remaining: 1.03s
# 874:	learn: 0.0444696	total: 7.13s	remaining: 1.02s
# 875:	learn: 0.0444247	total: 7.14s	remaining: 1.01s
# 876:	learn: 0.0443918	total: 7.15s	remaining: 1s
# 877:	learn: 0.0443636	total: 7.16s	remaining: 995ms
# 878:	learn: 0.0443289	total: 7.17s	remaining: 986ms
# 879:	learn: 0.0442885	total: 7.17s	remaining: 978ms
# 880:	learn: 0.0442765	total: 7.18s	remaining: 970ms
# 881:	learn: 0.0442061	total: 7.19s	remaining: 962ms
# 882:	learn: 0.0441944	total: 7.2s	remaining: 954ms
# 883:	learn: 0.0441722	total: 7.2s	remaining: 945ms
# 884:	learn: 0.0441432	total: 7.21s	remaining: 937ms
# 885:	learn: 0.0440894	total: 7.22s	remaining: 929ms
# 886:	learn: 0.0440366	total: 7.23s	remaining: 921ms
# 887:	learn: 0.0439887	total: 7.24s	remaining: 913ms
# 888:	learn: 0.0439541	total: 7.24s	remaining: 904ms
# 889:	learn: 0.0438948	total: 7.25s	remaining: 896ms
# 890:	learn: 0.0438644	total: 7.26s	remaining: 888ms
# 891:	learn: 0.0438266	total: 7.27s	remaining: 880ms
# 892:	learn: 0.0438059	total: 7.28s	remaining: 872ms
# 893:	learn: 0.0437661	total: 7.28s	remaining: 864ms
# 894:	learn: 0.0437398	total: 7.29s	remaining: 855ms
# 895:	learn: 0.0437235	total: 7.3s	remaining: 847ms
# 896:	learn: 0.0436902	total: 7.31s	remaining: 839ms
# 897:	learn: 0.0436505	total: 7.32s	remaining: 831ms
# 898:	learn: 0.0436023	total: 7.32s	remaining: 823ms
# 899:	learn: 0.0435851	total: 7.33s	remaining: 815ms
# 900:	learn: 0.0435552	total: 7.34s	remaining: 806ms
# 901:	learn: 0.0435379	total: 7.35s	remaining: 798ms
# 902:	learn: 0.0435102	total: 7.35s	remaining: 790ms
# 903:	learn: 0.0434736	total: 7.36s	remaining: 782ms
# 904:	learn: 0.0434469	total: 7.37s	remaining: 774ms
# 905:	learn: 0.0433959	total: 7.38s	remaining: 765ms
# 906:	learn: 0.0433747	total: 7.38s	remaining: 757ms
# 907:	learn: 0.0433281	total: 7.39s	remaining: 749ms
# 908:	learn: 0.0433088	total: 7.4s	remaining: 741ms
# 909:	learn: 0.0432790	total: 7.41s	remaining: 733ms
# 910:	learn: 0.0432368	total: 7.42s	remaining: 725ms
# 911:	learn: 0.0432036	total: 7.42s	remaining: 716ms
# 912:	learn: 0.0431670	total: 7.43s	remaining: 708ms
# 913:	learn: 0.0431254	total: 7.44s	remaining: 700ms
# 914:	learn: 0.0430728	total: 7.45s	remaining: 692ms
# 915:	learn: 0.0429983	total: 7.46s	remaining: 684ms
# 916:	learn: 0.0429692	total: 7.46s	remaining: 676ms
# 917:	learn: 0.0429545	total: 7.47s	remaining: 668ms
# 918:	learn: 0.0429387	total: 7.48s	remaining: 659ms
# 919:	learn: 0.0428971	total: 7.49s	remaining: 651ms
# 920:	learn: 0.0428686	total: 7.5s	remaining: 643ms
# 921:	learn: 0.0427988	total: 7.5s	remaining: 635ms
# 922:	learn: 0.0427475	total: 7.53s	remaining: 628ms
# 923:	learn: 0.0426862	total: 7.53s	remaining: 620ms
# 924:	learn: 0.0426642	total: 7.54s	remaining: 611ms
# 925:	learn: 0.0426456	total: 7.55s	remaining: 603ms
# 926:	learn: 0.0426267	total: 7.56s	remaining: 595ms
# 927:	learn: 0.0425946	total: 7.56s	remaining: 587ms
# 928:	learn: 0.0425421	total: 7.57s	remaining: 579ms
# 929:	learn: 0.0425139	total: 7.58s	remaining: 571ms
# 930:	learn: 0.0424802	total: 7.59s	remaining: 562ms
# 931:	learn: 0.0424697	total: 7.59s	remaining: 554ms
# 932:	learn: 0.0424271	total: 7.6s	remaining: 546ms
# 933:	learn: 0.0423937	total: 7.61s	remaining: 538ms
# 934:	learn: 0.0423616	total: 7.62s	remaining: 530ms
# 935:	learn: 0.0423193	total: 7.63s	remaining: 521ms
# 936:	learn: 0.0422830	total: 7.63s	remaining: 513ms
# 937:	learn: 0.0422274	total: 7.64s	remaining: 505ms
# 938:	learn: 0.0422000	total: 7.65s	remaining: 497ms
# 939:	learn: 0.0421525	total: 7.66s	remaining: 489ms
# 940:	learn: 0.0421018	total: 7.66s	remaining: 481ms
# 941:	learn: 0.0420454	total: 7.67s	remaining: 472ms
# 942:	learn: 0.0420144	total: 7.68s	remaining: 464ms
# 943:	learn: 0.0419875	total: 7.69s	remaining: 456ms
# 944:	learn: 0.0419556	total: 7.7s	remaining: 448ms
# 945:	learn: 0.0419057	total: 7.7s	remaining: 440ms
# 946:	learn: 0.0418739	total: 7.71s	remaining: 432ms
# 947:	learn: 0.0418464	total: 7.72s	remaining: 423ms
# 948:	learn: 0.0418217	total: 7.73s	remaining: 415ms
# 949:	learn: 0.0417698	total: 7.74s	remaining: 407ms
# 950:	learn: 0.0417295	total: 7.74s	remaining: 399ms
# 951:	learn: 0.0417019	total: 7.75s	remaining: 391ms
# 952:	learn: 0.0416651	total: 7.76s	remaining: 383ms
# 953:	learn: 0.0416439	total: 7.77s	remaining: 375ms
# 954:	learn: 0.0416236	total: 7.77s	remaining: 366ms
# 955:	learn: 0.0415899	total: 7.78s	remaining: 358ms
# 956:	learn: 0.0415716	total: 7.79s	remaining: 350ms
# 957:	learn: 0.0415560	total: 7.8s	remaining: 342ms
# 958:	learn: 0.0415084	total: 7.81s	remaining: 334ms
# 959:	learn: 0.0414625	total: 7.81s	remaining: 326ms
# 960:	learn: 0.0414336	total: 7.82s	remaining: 317ms
# 961:	learn: 0.0414070	total: 7.83s	remaining: 309ms
# 962:	learn: 0.0413943	total: 7.84s	remaining: 301ms
# 963:	learn: 0.0413517	total: 7.84s	remaining: 293ms
# 964:	learn: 0.0413223	total: 7.85s	remaining: 285ms
# 965:	learn: 0.0413063	total: 7.86s	remaining: 277ms
# 966:	learn: 0.0412768	total: 7.87s	remaining: 269ms
# 967:	learn: 0.0412399	total: 7.88s	remaining: 260ms
# 968:	learn: 0.0411955	total: 7.89s	remaining: 252ms
# 969:	learn: 0.0411494	total: 7.89s	remaining: 244ms
# 970:	learn: 0.0411100	total: 7.9s	remaining: 236ms
# 971:	learn: 0.0410837	total: 7.91s	remaining: 228ms
# 972:	learn: 0.0410612	total: 7.92s	remaining: 220ms
# 973:	learn: 0.0409940	total: 7.93s	remaining: 212ms
# 974:	learn: 0.0409735	total: 7.93s	remaining: 203ms
# 975:	learn: 0.0409606	total: 7.94s	remaining: 195ms
# 976:	learn: 0.0408632	total: 7.95s	remaining: 187ms
# 977:	learn: 0.0408403	total: 7.96s	remaining: 179ms
# 978:	learn: 0.0408159	total: 7.97s	remaining: 171ms
# 979:	learn: 0.0407803	total: 7.97s	remaining: 163ms
# 980:	learn: 0.0407334	total: 7.98s	remaining: 155ms
# 981:	learn: 0.0406985	total: 7.99s	remaining: 146ms
# 982:	learn: 0.0406597	total: 8s	remaining: 138ms
# 983:	learn: 0.0406248	total: 8.01s	remaining: 130ms
# 984:	learn: 0.0405827	total: 8.01s	remaining: 122ms
# 985:	learn: 0.0405379	total: 8.02s	remaining: 114ms
# 986:	learn: 0.0405131	total: 8.03s	remaining: 106ms
# 987:	learn: 0.0404885	total: 8.04s	remaining: 97.6ms
# 988:	learn: 0.0404519	total: 8.05s	remaining: 89.5ms
# 989:	learn: 0.0404269	total: 8.05s	remaining: 81.4ms
# 990:	learn: 0.0404120	total: 8.06s	remaining: 73.2ms
# 991:	learn: 0.0403773	total: 8.07s	remaining: 65.1ms
# 992:	learn: 0.0403549	total: 8.08s	remaining: 57ms
# 993:	learn: 0.0403093	total: 8.09s	remaining: 48.8ms
# 994:	learn: 0.0402811	total: 8.1s	remaining: 40.7ms
# 995:	learn: 0.0402588	total: 8.1s	remaining: 32.5ms
# 996:	learn: 0.0402386	total: 8.11s	remaining: 24.4ms
# 997:	learn: 0.0401924	total: 8.12s	remaining: 16.3ms
# 998:	learn: 0.0401718	total: 8.13s	remaining: 8.13ms
# 999:	learn: 0.0401457	total: 8.13s	remaining: 0us

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics import (
    precision_recall_curve, roc_curve, roc_auc_score, average_precision_score,
    recall_score, precision_score, f1_score, matthews_corrcoef
)

from pprint import pprint

# function to train models and evaluate the performance

def run_model(clf, X_test, y_test): 
    if (type(clf).__name__ == 'SVC'):
        y_score = clf.decision_function(X_test)
    else: y_score = clf.predict_proba(X_test)[:, 1]

    auc = roc_auc_score(y_test, y_score)
    ap = average_precision_score(y_test, y_score)

    if (type(clf).__name__ == 'SVC'):
        y_pred = (y_score >= 0)
    else: y_pred = (y_score >= 0.5)
    recall_no = recall_score(y_test, y_pred)
    preci_no = precision_score(y_test, y_pred)
    f1_no = f1_score(y_test, y_pred)
    mcc_no = matthews_corrcoef(y_test, y_pred)

    precision, recall, thresholds = precision_recall_curve(y_test, y_score)

    # Maximizing F1-score
    f1_val = (2 * precision * recall) / (precision + recall)
    f1_val[np.isinf(f1_val)] = np.nan

    i = np.nanargmax(f1_val)
    best_thre = thresholds[i]

    y_pred = (y_score >= best_thre)
    recall_opt = recall_score(y_test, y_pred)
    preci_opt = precision_score(y_test, y_pred)
    f1_opt = f1_score(y_test, y_pred)
    mcc_opt = matthews_corrcoef(y_test, y_pred)


    res = {'ap': ap, 'auc': auc, 'recall': recall_no, 'precision': preci_no, 
           'f1': f1_no, 'mcc_no': mcc_no, 'recall(opt)': recall_opt, 
           'precision(opt)': preci_opt, 'f1(opt)': f1_opt, 'mcc(opt)': mcc_opt,
           'threshold': best_thre}
    print("model: ", type(clf).__name__)
    pprint(res, sort_dicts=False)
    return res

# %%
# now we train several models, with the different UnderSampling techniques and


res_stk = {}

for sampler in sampler_map.keys():
    print(sampler)
    
    # set up the classifier
    res_stk[sampler] = run_model(stk[sampler], X_va, y_va)
    print()
# Out:
# smote
# model:  StackingClassifier
# {'ap': 0.4244705918436847,
#  'auc': 0.8728438150211424,
#  'recall': 0.45592705167173253,
#  'precision': 0.4658385093167702,
#  'f1': 0.4608294930875576,
#  'mcc_no': 0.43173938978641857,
#  'recall(opt)': 0.5106382978723404,
#  'precision(opt)': 0.44680851063829785,
#  'f1(opt)': 0.4765957446808511,
#  'mcc(opt)': 0.4471024044466587,
#  'threshold': 0.3895774348149278}
#
# adasyn
# model:  StackingClassifier
# {'ap': 0.43340063889712205,
#  'auc': 0.8740549777019904,
#  'recall': 0.49544072948328266,
#  'precision': 0.47246376811594204,
#  'f1': 0.4836795252225519,
#  'mcc_no': 0.4549120168329319,
#  'recall(opt)': 0.5015197568389058,
#  'precision(opt)': 0.47413793103448276,
#  'f1(opt)': 0.4874446085672083,
#  'mcc(opt)': 0.4588184954999951,
#  'threshold': 0.49523789504047855}
#
# cnn
# model:  StackingClassifier
# {'ap': 0.4606036368996149,
#  'auc': 0.8929617318011454,
#  'recall': 0.40425531914893614,
#  'precision': 0.5757575757575758,
#  'f1': 0.475,
#  'mcc_no': 0.45930525848051795,
#  'recall(opt)': 0.49544072948328266,
#  'precision(opt)': 0.4780058651026393,
#  'f1(opt)': 0.48656716417910445,
#  'mcc(opt)': 0.45807305498608775,
#  'threshold': 0.4189507588138616}
#
# enn
# model:  StackingClassifier
# {'ap': 0.45485487115219586,
#  'auc': 0.868546710759717,
#  'recall': 0.5045592705167173,
#  'precision': 0.5015105740181269,
#  'f1': 0.503030303030303,
#  'mcc_no': 0.47579952012155385,
#  'recall(opt)': 0.5015197568389058,
#  'precision(opt)': 0.5339805825242718,
#  'f1(opt)': 0.5172413793103449,
#  'mcc(opt)': 0.4920095505399648,
#  'threshold': 0.5761936480746567}
#
# tomek
# model:  StackingClassifier
# {'ap': 0.47527491654081283,
#  'auc': 0.8883366043136569,
#  'recall': 0.3373860182370821,
#  'precision': 0.6271186440677966,
#  'f1': 0.43873517786561267,
#  'mcc_no': 0.43952815730711514,
#  'recall(opt)': 0.5106382978723404,
#  'precision(opt)': 0.509090909090909,
#  'f1(opt)': 0.5098634294385432,
#  'mcc(opt)': 0.4830480069640679,
#  'threshold': 0.18611224906467957}
#
# smoteenn
# model:  StackingClassifier
# {'ap': 0.41574591755949303,
#  'auc': 0.8756726368575981,
#  'recall': 0.5866261398176292,
#  'precision': 0.33104631217838765,
#  'f1': 0.4232456140350877,
#  'mcc_no': 0.40057679713141797,
#  'recall(opt)': 0.5045592705167173,
#  'precision(opt)': 0.4598337950138504,
#  'f1(opt)': 0.4811594202898551,
#  'mcc(opt)': 0.45197229547775836,
#  'threshold': 0.922106290701332}

# %%
import joblib

names = ['stk']
for name in names:
    model_dict = {
        'model': globals()[f'{name}'],
        'result': globals()[f'res_{name}']
    }
    joblib.dump(model_dict, f'models/imbal_opt_{name}_1_2.pkl')

# %% [markdown]
# ## Final Test

# %%
test_set = pd.read_csv(f"datasets/test_set_{seed}_t_2.csv")

# %%
X_te = full_pipeline.transform(test_set)
y_te = test_set['is_drop'].copy()

X_te = pd.DataFrame(X_te, columns=full_pipeline.get_feature_names_out())

# %%
# function to train models and evaluate the performance

def test_model(clf, X_test, y_test, thre): 
    if (type(clf).__name__ == 'SVC'):
        y_score = clf.decision_function(X_test)
    else: y_score = clf.predict_proba(X_test)[:, 1]

    auc = roc_auc_score(y_test, y_score)
    ap = average_precision_score(y_test, y_score)

    if (type(clf).__name__ == 'SVC'):
        y_pred = (y_score >= 0)
    else: y_pred = (y_score >= 0.5)
    recall_no = recall_score(y_test, y_pred)
    preci_no = precision_score(y_test, y_pred)
    f1_no = f1_score(y_test, y_pred)
    mcc_no = matthews_corrcoef(y_test, y_pred)

    # Maximizing F1-score
    y_pred = (y_score >= thre)
    recall_opt = recall_score(y_test, y_pred)
    preci_opt = precision_score(y_test, y_pred)
    f1_opt = f1_score(y_test, y_pred)
    mcc_opt = matthews_corrcoef(y_test, y_pred)

    res = {'ap': ap, 'auc': auc, 'recall': recall_no, 'precision': preci_no, 
           'f1': f1_no, 'mcc_no': mcc_no, 'recall(opt)': recall_opt, 
           'precision(opt)': preci_opt, 'f1(opt)': f1_opt, 'mcc(opt)': mcc_opt,
           'threshold': thre}
    print("model: ", type(clf).__name__)
    pprint(res, sort_dicts=False)
    return res

# %%
# now we train several models, with the different UnderSampling techniques and
# with cross-validation 

# save results

test_stk = {}

for sampler in sampler_map.keys():
    print(sampler)
    
    # set up the classifier
    test_stk[sampler] = test_model(stk[sampler], X_te, y_te, res_stk[sampler]['threshold'])

    print()
# Out:
# smote
# model:  StackingClassifier
# {'ap': 0.43240986505260165,
#  'auc': 0.8870226446306787,
#  'recall': 0.44339622641509435,
#  'precision': 0.4577922077922078,
#  'f1': 0.4504792332268371,
#  'mcc_no': 0.422116689202981,
#  'recall(opt)': 0.4716981132075472,
#  'precision(opt)': 0.4155124653739612,
#  'f1(opt)': 0.4418262150220913,
#  'mcc(opt)': 0.41142058530372727,
#  'threshold': 0.3895774348149278}
#
# adasyn
# model:  StackingClassifier
# {'ap': 0.4469783258422672,
#  'auc': 0.890631843979379,
#  'recall': 0.46855345911949686,
#  'precision': 0.4501510574018127,
#  'f1': 0.4591679506933744,
#  'mcc_no': 0.43021256896454807,
#  'recall(opt)': 0.4716981132075472,
#  'precision(opt)': 0.4491017964071856,
#  'f1(opt)': 0.4601226993865031,
#  'mcc(opt)': 0.43113187859009117,
#  'threshold': 0.49523789504047855}
#
# cnn
# model:  StackingClassifier
# {'ap': 0.45784273626721267,
#  'auc': 0.9024665636655899,
#  'recall': 0.37735849056603776,
#  'precision': 0.5607476635514018,
#  'f1': 0.45112781954887216,
#  'mcc_no': 0.4373018191528589,
#  'recall(opt)': 0.5094339622641509,
#  'precision(opt)': 0.4550561797752809,
#  'f1(opt)': 0.4807121661721068,
#  'mcc(opt)': 0.452571217914626,
#  'threshold': 0.4189507588138616}
#
# enn
# model:  StackingClassifier
# {'ap': 0.45481687520588204,
#  'auc': 0.8810152888972123,
#  'recall': 0.48742138364779874,
#  'precision': 0.484375,
#  'f1': 0.48589341692789967,
#  'mcc_no': 0.458761847875635,
#  'recall(opt)': 0.4748427672955975,
#  'precision(opt)': 0.5067114093959731,
#  'f1(opt)': 0.4902597402597403,
#  'mcc(opt)': 0.46462996753613256,
#  'threshold': 0.5761936480746567}
#
# tomek
# model:  StackingClassifier
# {'ap': 0.4901519958418761,
#  'auc': 0.8989999011605827,
#  'recall': 0.3490566037735849,
#  'precision': 0.676829268292683,
#  'f1': 0.4605809128630705,
#  'mcc_no': 0.46792571834574365,
#  'recall(opt)': 0.48742138364779874,
#  'precision(opt)': 0.5132450331125827,
#  'f1(opt)': 0.5,
#  'mcc(opt)': 0.47458544157648075,
#  'threshold': 0.18611224906467957}
#
# smoteenn
# model:  StackingClassifier
# {'ap': 0.4146180622413206,
#  'auc': 0.8867739854654035,
#  'recall': 0.6194968553459119,
#  'precision': 0.3384879725085911,
#  'f1': 0.43777777777777777,
#  'mcc_no': 0.4201200579150722,
#  'recall(opt)': 0.46540880503144655,
#  'precision(opt)': 0.4192634560906516,
#  'f1(opt)': 0.44113263785394935,
#  'mcc(opt)': 0.4107375251008634,
#  'threshold': 0.922106290701332}
